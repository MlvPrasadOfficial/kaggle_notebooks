# %% [markdown]
# ## Chapter 1: Introduction to Matplotlib
# - [What is Matplotlib?](code/chapter1/what_is_matplotlib.py)
# - [Installing Matplotlib](code/chapter1/installing_matplotlib.py)
# - [Basic plotting with Matplotlib](code/chapter1/basic_plotting.py)
# - [Anatomy of a Matplotlib figure](code/chapter1/anatomy_of_figure.py)
#
# ## Chapter 2: Line Plots
# - [Creating a simple line plot](code/chapter2/simple_line_plot.py)
# - [Customizing line styles and colors](code/chapter2/customizing_styles_colors.py)
# - [Adding labels and titles](code/chapter2/adding_labels_titles.py)
# - [Plotting multiple lines](code/chapter2/plotting_multiple_lines.py)
#
# ## Chapter 3: Scatter Plots
# - [Creating a basic scatter plot](code/chapter3/basic_scatter_plot.py)
# - [Customizing marker styles and sizes](code/chapter3/customizing_markers.py)
# - [Adding labels and titles](code/chapter3/adding_labels_titles.py)
# - [Highlighting specific data points](code/chapter3/highlighting_data_points.py)
#
# ## Chapter 4: Bar Plots
# - [Creating vertical and horizontal bar plots](code/chapter4/vertical_horizontal_bar_plots.py)
# - [Customizing bar colors and widths](code/chapter4/customizing_colors_widths.py)
# - [Grouped and stacked bar plots](code/chapter4/grouped_stacked_bar_plots.py)
# - [Adding error bars](code/chapter4/adding_error_bars.py)
#
# ## Chapter 5: Histograms
# - [Creating a histogram](code/chapter5/creating_histogram.py)
# - [Customizing bin sizes and colors](code/chapter5/customizing_bins_colors.py)
# - [Overlaying multiple histograms](code/chapter5/overlaying_histograms.py)
# - [Probability density estimation](code/chapter5/probability_density_estimation.py)
#
# ## Chapter 6: Pie Charts
# - [Creating a basic pie chart](code/chapter6/basic_pie_chart.py)
# - [Exploding and highlighting slices](code/chapter6/exploding_highlighting_slices.py)
# - [Adding a legend and labels](code/chapter6/adding_legend_labels.py)
# - [Donut charts](code/chapter6/donut_charts.py)
#
# ## Chapter 7: Box Plots
# - [Creating a box plot](code/chapter7/creating_box_plot.py)
# - [Customizing whiskers and outliers](code/chapter7/customizing_whiskers_outliers.py)
# - [Grouped and stacked box plots](code/chapter7/grouped_stacked_box_plots.py)
# - [Violin plots](code/chapter7/violin_plots.py)
#
# ## Chapter 8: Polar Plots
# - [Creating polar plots](code/chapter8/creating_polar_plots.py)
# - [Customizing tick labels and gridlines](code/chapter8/customizing_tick_labels_gridlines.py)
# - [Adding multiple plots in polar coordinates](code/chapter8/multiple_plots_polar_coordinates.py)
# - [Wind rose plots](code/chapter8/wind_rose_plots.py)
#
# ## Chapter 9: 3D Plots
# - [Creating 3D scatter plots](code/chapter9/creating_3d_scatter_plots.py)
# - [Surface plots](code/chapter9/surface_plots.py)
# - [Wireframe plots](code/chapter9/wireframe_plots.py)
# - [Contour plots](code/chapter9/contour_plots.py)
#
# ## Chapter 10: Subplots
# - [Creating subplots with subplot](code/chapter10/creating_subplots.py)
# - [Grid of subplots with subplots](code/chapter10/grid_of_subplots.py)
# - [Sharing axes between subplots](code/chapter10/sharing_axes_subplots.py)
# - [Creating insets and multiple axes](code/chapter10/creating_insets_multiple_axes.py)
#
# ## Chapter 11: Annotations and Text
# - [Adding text to plots](code/chapter11/adding_text_plots.py)
# - [Annotations with arrows and lines](code/chapter11/annotations_arrows_lines.py)
# - [Adding mathematical expressions](code/chapter11/adding_mathematical_expressions.py)
# - [Watermark and image annotations](code/chapter11/watermark_image_annotations.py)
#
# ## Chapter 12: Legends and Colorbars
# - [Creating legends](code/chapter12/creating_legends.py)
# - [Customizing legend appearance](code/chapter12/customizing_legend_appearance.py)
# - [Colorbars for scalar plots](code/chapter12/colorbars_scalar_plots.py)
# - [Color normalization and mapping](code/chapter12/color_normalization_mapping.py)
#
# ## Chapter 13: Ticks and Spines
# - [Customizing tick locations and labels](code/chapter13/customizing_ticks_locations_labels.py)
# - [Setting tick formats](code/chapter13/setting_tick_formats.py)
# - [Hiding and customizing spines](code/chapter13/hiding_customizing_spines.py)
# - [Twin axes and logarithmic scales](code/chapter13/twin_axes_logarithmic_scales.py)
#
# ## Chapter 14: Styles and Themes
# - [Applying styles to plots](code/chapter14/applying_styles_plots.py)
# - [Creating custom styles](code/chapter14/creating_custom_styles.py)
# - [Using pre-defined themes](code/chapter14/using_predefined_themes.py)
# - [Combining styles and themes](code/chapter14/combining_styles_themes.py)
#
# ## Chapter 15: Saving and Exporting Plots
# - [Saving plots to image files](code/chapter15/saving_plots_image_files.py)
# - [Exporting plots to different file formats](code/chapter15/exporting_plots_file_formats.py)
# - [Saving plots with transparent backgrounds](code/chapter15/saving_plots_transparent_backgrounds.py)
# - [Saving plots with specified DPI](code/chapter15/saving_plots_specified_dpi.py)
#
# ## Chapter 16: Interactive Plots
# - [Introduction to interactive plots](code/chapter16/introduction_interactive_plots.py)
# - [Interacting with plots using widgets](code/chapter16/interacting_plots_widgets.py)
# - [Embedding interactive plots in web applications](code/chapter16/embedding_interactive_plots_web_apps.py)
# - [Animating plots](code/chapter16/animating_plots.py)
#
# ## Chapter 17: Advanced Customizations
# - [Customizing figure size and resolution](code/chapter17/customizing_figure_size_resolution.py)
# - [Adding annotations and shapes to plots](code/chapter17/adding_annotations_shapes_plots.py)
# - [Fine-tuning plot appearance with rcParams](code/chapter17/fine_tuning_plot_appearance_rcparams.py)
# - [Using custom color maps](code/chapter17/using_custom_color_maps.py)
#
# ## Chapter 18: Advanced Plotting Techniques
# - [Streamplots and vector fields](code/chapter18/streamplots_vector_fields.py)
# - [Quiver plots](code/chapter18/quiver_plots.py)
# - [2D and 3D histograms](code/chapter18/2D_3D_histograms.py)
# - [Plotting on maps](code/chapter18/plotting_on_maps.py)
#
# ## Chapter 19: Working with Dates and Times
# - [Plotting time series data](code/chapter19/plotting_time_series_data.py)
# - [Customizing date and time formatting](code/chapter19/customizing_date_time_formatting.py)
# - [Handling time zones](code/chapter19/handling_time_zones.py)
# - [Plotting events and intervals](code/chapter19/plotting_events_intervals.py)
#
# ## Chapter 20: Statistical Visualization
# - [Box plots and violin plots for distribution visualization](code/chapter20/box_violin_plots_distribution.py)
# - [Heatmaps and correlation matrices](code/chapter20/heatmaps_correlation_matrices.py)
# - [Scatter plots with regression lines](code/chapter20/scatter_plots_regression_lines.py)
# - [Visualizing uncertainty with error bars](code/chapter20/visualizing_uncertainty_error_bars.py)
#
# ## Chapter 21: Geographic Data Visualization
# - [Plotting data on maps](code/chapter21/plotting_data_maps.py)
# - [Choropleth maps](code/chapter21/choropleth_maps.py)
# - [Point maps and bubble maps](code/chapter21/point_maps_bubble_maps.py)
# - [Geospatial projections and transformations](code/chapter21/geospatial_projections_transformations.py)
#
# ## Chapter 22: Interactive Geospatial Visualization
# - [Interactive maps with tooltips and interactivity](code/chapter22/interactive_maps_tooltips_interactivity.py)
# - [Adding layers and overlays to maps](code/chapter22/adding_layers_overlays_maps.py)
# - [Geospatial clustering and heatmaps](code/chapter22/geospatial_clustering_heatmaps.py)
# - [Animated geospatial visualizations](code/chapter22/animated_geospatial_visualizations.py)
#
# ## Chapter 23: Network Visualization
# - [Visualizing networks and graphs](code/chapter23/visualizing_networks_graphs.py)
# - [Node and edge customization](code/chapter23/node_edge_customization.py)
# - [Community detection and layout algorithms](code/chapter23/community_detection_layout_algorithms.py)
# - [Interactive network visualization](code/chapter23/interactive_network_visualization.py)
#
# ## Chapter 24: Plotting with Pandas
# - [Plotting with Pandas Series and DataFrames](code/chapter24/plotting_with_pandas_series_dataframes.py)
# - [Grouping and aggregating data for visualization](code/chapter24/grouping_aggregating_data_visualization.py)
# - [Plotting time series data with Pandas](code/chapter24/plotting_time_series_data_pandas.py)
# - [Combining Matplotlib and Pandas plots](code/chapter24/combining_matplotlib_pandas_plots.py)
#
# ## Chapter 25: Plotting with Seaborn
# - [Introduction to Seaborn library](code/chapter25/introduction_to_seaborn.py)
# - [Plotting statistical relationships with Seaborn](code/chapter25/plotting_statistical_relationships_seaborn.py)
# - [Visualizing categorical data with Seaborn](code/chapter25/visualizing_categorical_data_seaborn.py)
# - [Customizing Seaborn plots](code/chapter25/customizing_seaborn_plots.py)

# %% [markdown]
# ## Chapter 26: Plotting with Plotly
# - [Introduction to Plotly library](code/chapter26/introduction_to_plotly.py)
# - [Creating interactive plots with Plotly](code/chapter26/creating_interactive_plots.py)
# - [Customizing Plotly plots](code/chapter26/customizing_plotly_plots.py)
# - [Embedding Plotly plots in web applications](code/chapter26/embedding_plotly_plots.py)
#
# ## Chapter 27: Plotting with ggplot
# - [Introduction to ggplot library](code/chapter27/introduction_to_ggplot.py)
# - [Applying grammar of graphics principles with ggplot](code/chapter27/applying_grammar_graphics.py)
# - [Customizing ggplot plots](code/chapter27/customizing_ggplot_plots.py)
# - [Combining ggplot and Matplotlib plots](code/chapter27/combining_ggplot_matplotlib.py)
#
# ## Chapter 28: Plotting with mpld3
# - [Introduction to mpld3 library](code/chapter28/introduction_to_mpld3.py)
# - [Creating interactive Matplotlib plots with mpld3](code/chapter28/creating_interactive_plots.py)
# - [Customizing mpld3 plots](code/chapter28/customizing_mpld3_plots.py)
# - [Embedding mpld3 plots in web applications](code/chapter28/embedding_mpld3_plots.py)
#
# ## Chapter 29: Visualizing Machine Learning Models
# - [Visualizing decision trees and random forests](code/chapter29/visualizing_decision_trees_random_forests.py)
# - [Plotting feature importances](code/chapter29/plotting_feature_importances.py)
# - [Visualizing clustering results](code/chapter29/visualizing_clustering_results.py)
# - [Plotting model evaluation metrics](code/chapter29/plotting_model_evaluation_metrics.py)
#
# ## Chapter 30: Visualizing Neural Networks
# - [Visualizing neural network architectures](code/chapter30/visualizing_neural_network_architectures.py)
# - [Activation maps and feature visualization](code/chapter30/activation_maps_feature_visualization.py)
# - [Visualizing training progress](code/chapter30/visualizing_training_progress.py)
# - [Plotting model performance metrics](code/chapter30/plotting_model_performance_metrics.py)
#
# ## Chapter 31: Geospatial Data Visualization with GeoPandas
# - [Introduction to GeoPandas library](code/chapter31/introduction_to_geopandas.py)
# - [Plotting geospatial data with GeoPandas](code/chapter31/plotting_geospatial_data.py)
# - [Overlaying geospatial data on maps](code/chapter31/overlaying_geospatial_data.py)
# - [Customizing geospatial plots](code/chapter31/customizing_geospatial_plots.py)
#
# ## Chapter 32: Plotting Time Series Data
# - [Basic time series plot with Matplotlib](code/chapter32/basic_time_series_plot.py)
# - [Seasonal decomposition and trend analysis](code/chapter32/seasonal_decomposition_trend_analysis.py)
# - [Plotting rolling statistics](code/chapter32/plotting_rolling_statistics.py)
# - [Visualizing time series forecasts](code/chapter32/visualizing_time_series_forecasts.py)
#
# ## Chapter 33: Visualization Best Practices
# - [Choosing the right plot type for your data](code/chapter33/choosing_plot_type.py)
# - [Effective use of colors and palettes](code/chapter33/effective_use_colors_palettes.py)
# - [Proper labeling and annotation](code/chapter33/proper_labeling_annotation.py)
# - [Designing clear and informative plots](code/chapter33/designing_clear_informative_plots.py)
#
# ## Chapter 34: Working with Large Datasets
# - [Plotting subsets of large datasets](code/chapter34/plotting_subsets_large_datasets.py)
# - [Aggregating and summarizing data for visualization](code/chapter34/aggregating_summarizing_data.py)
# - [Using interactive techniques for large datasets](code/chapter34/using_interactive_techniques.py)
# - [Plotting streaming data](code/chapter34/plotting_streaming_data.py)
#
# ## Chapter 35: Creating Publication-Quality Plots
# - [Customizing plot aesthetics](code/chapter35/customizing_plot_aesthetics.py)
# - [Fine-tuning plot elements for publication](code/chapter35/fine_tuning_plot_elements.py)
# - [Exporting plots in vector formats](code/chapter35/exporting_plots_vector_formats.py)
# - [Creating multipanel figures](code/chapter35/creating_multipanel_figures.py)
#
# ## Chapter 36: Animating Plots with Matplotlib
# - [Introduction to animation with Matplotlib](code/chapter36/introduction_animation_matplotlib.py)
# - [Creating basic animations](code/chapter36/creating_basic_animations.py)
# - [Fine-tuning animation parameters](code/chapter36/fine_tuning_animation_parameters.py)
# - [Saving and exporting animated plots](code/chapter36/saving_exporting_animated_plots.py)
#
# ## Chapter 37: Plotting with Geopandas and Plotly
# - [Combining geospatial data visualization with Plotly](code/chapter37/combining_geospatial_data_plotly.py)
# - [Creating interactive geospatial plots](code/chapter37/creating_interactive_geospatial_plots.py)
# - [Adding interactivity and tooltips to geospatial plots](code/chapter37/adding_interactivity_tooltips.py)
# - [Customizing geospatial plots with Plotly](code/chapter37/customizing_geospatial_plots_plotly.py)
#
# ## Chapter 38: Visualizing Data with Matplotlib and Machine Learning
# - [Visualizing data distributions with histograms and box plots](code/chapter38/visualizing_data_distributions.py)
# - [Feature analysis with scatter plots and parallel coordinates](code/chapter38/feature_analysis_scatter_plots_parallel_coordinates.py)
# - [Model evaluation and performance visualization](code/chapter38/model_evaluation_performance_visualization.py)
# - [Visualizing decision boundaries](code/chapter38/visualizing_decision_boundaries.py)
#
# ## Chapter 39: Interactive Data Exploration with Matplotlib and Jupyter Widgets
# - [Introduction to Jupyter widgets](code/chapter39/introduction_jupyter_widgets.py)
# - [Creating interactive plots with Matplotlib and Jupyter widgets](code/chapter39/creating_interactive_plots.py)
# - [Linking widgets with plot elements](code/chapter39/linking_widgets_plot_elements.py)
# - [Interactive data filtering and exploration](code/chapter39/interactive_data_filtering_exploration.py)
#
# ## Chapter 40: Advanced Plotting Techniques with Seaborn
# - [Styling plots with Seaborn themes and color palettes](code/chapter40/styling_plots_seaborn_themes_palettes.py)
# - [Advanced statistical visualization techniques with Seaborn](code/chapter40/advanced_statistical_visualization.py)
# - [Visualizing multivariate relationships with Seaborn](code/chapter40/visualizing_multivariate_relationships.py)
# - [Customizing Seaborn grids and facets](code/chapter40/customizing_seaborn_grids_facets.py)

# %% [markdown]
# ## Chapter 41: Plotting with Plotnine
# - [Introduction to the grammar of graphics with Plotnine](code/chapter41/introduction_grammar_graphics.py)
# - [Creating aesthetic mappings with Plotnine](code/chapter41/creating_aesthetic_mappings.py)
# - [Customizing Plotnine plots](code/chapter41/customizing_plotnine_plots.py)
# - [Combining Plotnine and Matplotlib plots](code/chapter41/combining_plotnine_matplotlib_plots.py)
#
# ## Chapter 42: Visualizing Uncertainty with Matplotlib
# - [Introduction to uncertainty visualization](code/chapter42/introduction_uncertainty_visualization.py)
# - [Plotting error bars and confidence intervals](code/chapter42/plotting_error_bars_confidence_intervals.py)
# - [Visualizing probability distributions](code/chapter42/visualizing_probability_distributions.py)
# - [Bayesian uncertainty visualization](code/chapter42/bayesian_uncertainty_visualization.py)
#
# ## Chapter 43: Plotting with Bokeh
# - [Introduction to Bokeh library](code/chapter43/introduction_to_bokeh.py)
# - [Creating interactive plots with Bokeh](code/chapter43/creating_interactive_plots.py)
# - [Customizing Bokeh plots](code/chapter43/customizing_bokeh_plots.py)
# - [Embedding Bokeh plots in web applications](code/chapter43/embedding_bokeh_plots.py)
#
# ## Chapter 44: Geographic Data Visualization with Folium
# - [Introduction to Folium library](code/chapter44/introduction_to_folium.py)
# - [Creating interactive maps with Folium](code/chapter44/creating_interactive_maps.py)
# - [Overlaying data on maps with Folium](code/chapter44/overlaying_data_on_maps.py)
# - [Customizing Folium maps](code/chapter44/customizing_folium_maps.py)
#
# ## Chapter 45: Plotting with Altair
# - [Introduction to Altair library](code/chapter45/introduction_to_altair.py)
# - [Creating declarative visualizations with Altair](code/chapter45/creating_declarative_visualizations.py)
# - [Customizing Altair plots](code/chapter45/customizing_altair_plots.py)
# - [Combining Altair and Matplotlib plots](code/chapter45/combining_altair_matplotlib_plots.py)
#
# ## Chapter 46: Visualizing Time Series Patterns
# - [Decomposing time series data](code/chapter46/decomposing_time_series.py)
# - [Plotting seasonality and trend components](code/chapter46/plotting_seasonality_trend_components.py)
# - [Visualizing autocorrelation and lagged relationships](code/chapter46/visualizing_autocorrelation_lagged_relationships.py)
# - [Plotting time series forecasting results](code/chapter46/plotting_time_series_forecasting.py)
#
# ## Chapter 47: Visualizing Networks with NetworkX
# - [Introduction to NetworkX library](code/chapter47/introduction_networkx.py)
# - [Creating network visualizations with NetworkX](code/chapter47/creating_network_visualizations.py)
# - [Customizing network plots](code/chapter47/customizing_network_plots.py)
# - [Visualizing network metrics and properties](code/chapter47/visualizing_network_metrics_properties.py)
#
# ## Chapter 48: Interactive Data Visualization with Plotly Express
# - [Introduction to Plotly Express](code/chapter48/introduction_to_plotly_express.py)
# - [Creating interactive plots with Plotly Express](code/chapter48/creating_interactive_plots.py)
# - [Customizing Plotly Express plots](code/chapter48/customizing_plotly_express_plots.py)
# - [Adding interactivity and animations](code/chapter48/adding_interactivity_animations.py)
#
# ## Chapter 49: Visualizing Geospatial Data with Basemap
# - [Introduction to Basemap library](code/chapter49/introduction_to_basemap.py)
# - [Creating geospatial plots with Basemap](code/chapter49/creating_geospatial_plots.py)
# - [Customizing Basemap plots](code/chapter49/customizing_basemap_plots.py)
# - [Geospatial projections and annotations](code/chapter49/geospatial_projections_annotations.py)
#
# ## Chapter 50: Advanced 3D Visualization with Matplotlib
# - [Advanced techniques for 3D plotting with Matplotlib](code/chapter50/advanced_3d_plotting.py)
# - [Visualizing complex 3D surfaces](code/chapter50/visualizing_complex_3d_surfaces.py)
# - [Animating 3D plots](code/chapter50/animating_3d_plots.py)
# - [Combining 3D plots with other plot types](code/chapter50/combining_3d_plots.py)
#
# ## Chapter 51: Visualizing Hierarchical Data
# - [Plotting dendrograms and tree diagrams](code/chapter51/plotting_dendrograms_tree_diagrams.py)
# - [Visualizing hierarchical clustering](code/chapter51/visualizing_hierarchical_clustering.py)
# - [Plotting sunburst and treemap plots](code/chapter51/plotting_sunburst_treemap_plots.py)
# - [Customizing hierarchical visualizations](code/chapter51/customizing_hierarchical_visualizations.py)
#
# ## Chapter 52: Plotting with HoloViews
# - [Introduction to HoloViews library](code/chapter52/introduction_to_holoviews.py)
# - [Creating interactive plots with HoloViews](code/chapter52/creating_interactive_plots.py)
# - [Customizing HoloViews plots](code/chapter52/customizing_holoviews_plots.py)
# - [Combining HoloViews and Matplotlib plots](code/chapter52/combining_holoviews_matplotlib_plots.py)
#
# ## Chapter 53: Visualizing Geographical Trajectories
# - [Plotting trajectories on maps](code/chapter53/plotting_trajectories_maps.py)
# - [Visualizing movement patterns and speeds](code/chapter53/visualizing_movement_patterns_speeds.py)
# - [Animated trajectory visualization](code/chapter53/animated_trajectory_visualization.py)
# - [Customizing trajectory plots](code/chapter53/customizing_trajectory_plots.py)
#
# ## Chapter 54: Visualizing Text Data
# - [Plotting word clouds](code/chapter54/plotting_word_clouds.py)
# - [Visualizing word frequencies and distributions](code/chapter54/visualizing_word_frequencies_distributions.py)
# - [Topic modeling visualization](code/chapter54/topic_modeling_visualization.py)
# - [Customizing text visualizations](code/chapter54/customizing_text_visualizations.py)
#
# ## Chapter 55: Plotting with Plotly Dash
# - [Introduction to Plotly Dash framework](code/chapter55/introduction_to_plotly_dash.py)
# - [Building interactive web-based data visualization apps](code/chapter55/building_interactive_apps.py)
# - [Customizing Plotly Dash components and layouts](code/chapter55/customizing_dash_components_layouts.py)
# - [Deploying Plotly Dash apps](code/chapter55/deploying_dash_apps.py)

# %% [markdown]
# ## Chapter 56: Visualizing Time Series Anomalies
# - [Detecting and visualizing anomalies in time series data](code/chapter56/detecting_visualizing_time_series_anomalies.py)
# - [Plotting anomaly scores and thresholds](code/chapter56/plotting_anomaly_scores_thresholds.py)
# - [Highlighting anomalous data points](code/chapter56/highlighting_anomalous_data_points.py)
# - [Interactive anomaly visualization](code/chapter56/interactive_anomaly_visualization.py)
#
# ## Chapter 57: Visualizing Data Distribution Shifts
# - [Detecting and visualizing distribution shifts in data](code/chapter57/detecting_visualizing_data_distribution_shifts.py)
# - [Plotting distribution comparison plots](code/chapter57/plotting_distribution_comparison_plots.py)
# - [Visualizing domain adaptation and transfer learning](code/chapter57/visualizing_domain_adaptation_transfer_learning.py)
# - [Customizing distribution shift visualizations](code/chapter57/customizing_distribution_shift_visualizations.py)
#
# ## Chapter 58: Plotting with Geoviews
# - [Introduction to Geoviews library](code/chapter58/introduction_to_geoviews.py)
# - [Creating geospatial visualizations with Geoviews](code/chapter58/creating_geospatial_visualizations.py)
# - [Customizing Geoviews plots](code/chapter58/customizing_geoviews_plots.py)
# - [Adding interactivity to Geoviews plots](code/chapter58/adding_interactivity_geoviews_plots.py)
#
# ## Chapter 59: Visualizing Ensembles and Uncertainty
# - [Plotting ensemble predictions and confidence intervals](code/chapter59/plotting_ensemble_predictions_confidence_intervals.py)
# - [Visualizing ensemble diversity and disagreement](code/chapter59/visualizing_ensemble_diversity_disagreement.py)
# - [Bayesian model averaging visualization](code/chapter59/bayesian_model_averaging_visualization.py)
# - [Customizing ensemble and uncertainty visualizations](code/chapter59/customizing_ensemble_uncertainty_visualizations.py)
#
# ## Chapter 60: Visualizing Graph Embeddings
# - [Plotting graph embeddings in low-dimensional space](code/chapter60/plotting_graph_embeddings.py)
# - [Visualizing node similarities and clusters](code/chapter60/visualizing_node_similarities_clusters.py)
# - [Dimensionality reduction techniques for graph embeddings](code/chapter60/dimensionality_reduction_graph_embeddings.py)
# - [Interactive graph embedding visualization](code/chapter60/interactive_graph_embedding_visualization.py)
#
# ## Chapter 61: Visualizing Multivariate Time Series
# - [Plotting multivariate time series data](code/chapter61/plotting_multivariate_time_series.py)
# - [Visualizing relationships and dependencies](code/chapter61/visualizing_relationships_dependencies.py)
# - [Clustering and segmentation of multivariate time series](code/chapter61/clustering_segmentation_multivariate_time_series.py)
# - [Interactive multivariate time series visualization](code/chapter61/interactive_multivariate_time_series_visualization.py)
#
# ## Chapter 62: Visualizing Imbalanced Data
# - [Plotting class distributions and imbalances](code/chapter62/plotting_class_distributions_imbalances.py)
# - [Visualizing precision-recall curves and ROC curves](code/chapter62/visualizing_precision_recall_roc_curves.py)
# - [Plotting cost-sensitive classification evaluation](code/chapter62/plotting_cost_sensitive_classification_evaluation.py)
# - [Customizing imbalanced data visualizations](code/chapter62/customizing_imbalanced_data_visualizations.py)
#
# ## Chapter 63: Plotting with Panel
# - [Introduction to Panel library](code/chapter63/introduction_to_panel.py)
# - [Creating dashboards and multi-view visualizations with Panel](code/chapter63/creating_dashboards_multi_view_visualizations.py)
# - [Customizing Panel layouts and interactions](code/chapter63/customizing_panel_layouts_interactions.py)
# - [Embedding Panel visualizations in web applications](code/chapter63/embedding_panel_visualizations.py)
#
# ## Chapter 64: Visualizing Interpretability of ML Models
# - [Plotting feature importances and contributions](code/chapter64/plotting_feature_importances_contributions.py)
# - [Partial dependence plots](code/chapter64/partial_dependence_plots.py)
# - [Visualizing decision boundaries and explanations](code/chapter64/visualizing_decision_boundaries_explanations.py)
# - [Customizing interpretability visualizations](code/chapter64/customizing_interpretability_visualizations.py)
#
# ## Chapter 65: Visualizing Neural Architecture Search
# - [Plotting neural architecture search results](code/chapter65/plotting_neural_architecture_search_results.py)
# - [Visualizing architecture performance and complexity trade-offs](code/chapter65/visualizing_architecture_performance_complexity.py)
# - [Customizing neural architecture search visualizations](code/chapter65/customizing_neural_architecture_search_visualizations.py)
# - [Interactive neural architecture search visualization](code/chapter65/interactive_neural_architecture_search_visualization.py)
#
# ## Chapter 66: Visualizing Time Series Forecast Uncertainty
# - [Plotting point forecasts and prediction intervals](code/chapter66/plotting_point_forecasts_prediction_intervals.py)
# - [Visualizing forecast error distributions](code/chapter66/visualizing_forecast_error_distributions.py)
# - [Uncertainty decomposition and contribution plots](code/chapter66/uncertainty_decomposition_contribution_plots.py)
# - [Customizing time series forecast uncertainty visualizations](code/chapter66/customizing_forecast_uncertainty_visualizations.py)
#
# ## Chapter 67: Plotting with Voy
# - [Introduction to Voy library](code/chapter67/introduction_to_voy.py)
# - [Creating interactive visualizations with Voy](code/chapter67/creating_interactive_visualizations.py)
# - [Customizing Voy plots](code/chapter67/customizing_voy_plots.py)
# - [Embedding Voy visualizations in web applications](code/chapter67/embedding_voy_visualizations.py)
#
# ## Chapter 68: Visualizing Word Embeddings
# - [Plotting word embeddings in 2D or 3D space](code/chapter68/plotting_word_embeddings_space.py)
# - [Visualizing word similarity and analogies](code/chapter68/visualizing_word_similarity_analogies.py)
# - [t-SNE visualization of word embeddings](code/chapter68/tsne_visualization_word_embeddings.py)
# - [Interactive word embedding visualization](code/chapter68/interactive_word_embedding_visualization.py)
#
# ## Chapter 69: Visualizing Recommendation Systems
# - [Plotting user-item interactions and ratings](code/chapter69/plotting_user_item_interactions_ratings.py)
# - [Visualizing item similarities and recommendations](code/chapter69/visualizing_item_similarities_recommendations.py)
# - [Interactive recommendation system visualization](code/chapter69/interactive_recommendation_system_visualization.py)
# - [Customizing recommendation system visualizations](code/chapter69/customizing_recommendation_system_visualizations.py)
#
# ## Chapter 70: Plotting with Glue
# - [Introduction to Glue library](code/chapter70/introduction_to_glue.py)
# - [Creating linked and synchronized visualizations with Glue](code/chapter70/creating_linked_synchronized_visualizations.py)
# - [Customizing Glue plots](code/chapter70/customizing_glue_plots.py)
# - [Exploring multi-dimensional data with Glue](code/chapter70/exploring_multidimensional_data_glue.py)

# %% [markdown]
# ## Chapter 71: Visualizing Neural Network Training
# - [Plotting training and validation curves](code/chapter71/plotting_training_validation_curves.py)
# - [Visualizing learning rate schedules](code/chapter71/visualizing_learning_rate_schedules.py)
# - [Plotting model performance during training](code/chapter71/plotting_model_performance_training.py)
# - [Customizing neural network training visualizations](code/chapter71/customizing_neural_network_training_visualizations.py)
#
# ## Chapter 72: Visualizing Data Augmentation Effects
# - [Plotting original and augmented data samples](code/chapter72/plotting_original_augmented_samples.py)
# - [Visualizing data transformations and distortions](code/chapter72/visualizing_data_transformations_distortions.py)
# - [Comparing augmented data distributions](code/chapter72/comparing_augmented_data_distributions.py)
# - [Customizing data augmentation visualizations](code/chapter72/customizing_data_augmentation_visualizations.py)
#
# ## Chapter 73: Visualizing GANs and Generative Models
# - [Plotting generated samples from GANs](code/chapter73/plotting_generated_samples_gans.py)
# - [Visualizing latent space interpolations](code/chapter73/visualizing_latent_space_interpolations.py)
# - [Conditional generation visualization](code/chapter73/conditional_generation_visualization.py)
# - [Customizing GAN and generative model visualizations](code/chapter73/customizing_gan_generative_model_visualizations.py)
#
# ## Chapter 74: Visualizing Autoencoders and Dimensionality Reduction
# - [Plotting encoder and decoder architectures](code/chapter74/plotting_encoder_decoder_architectures.py)
# - [Visualizing latent space representations](code/chapter74/visualizing_latent_space_representations.py)
# - [Reconstruction visualization](code/chapter74/reconstruction_visualization.py)
# - [Customizing autoencoder and dimensionality reduction visualizations](code/chapter74/customizing_autoencoder_dimensionality_reduction_visualizations.py)
#
# ## Chapter 75: Visualizing Neural Style Transfer
# - [Plotting content and style images](code/chapter75/plotting_content_style_images.py)
# - [Visualizing style transfer process and iterations](code/chapter75/visualizing_style_transfer_process_iterations.py)
# - [Feature visualization and analysis](code/chapter75/feature_visualization_analysis.py)
# - [Customizing neural style transfer visualizations](code/chapter75/customizing_neural_style_transfer_visualizations.py)
#
# ## Chapter 76: Visualizing Adversarial Attacks and Defenses
# - [Plotting adversarial examples and perturbations](code/chapter76/plotting_adversarial_examples_perturbations.py)
# - [Visualizing attack success rates](code/chapter76/visualizing_attack_success_rates.py)
# - [Defense evaluation and visualization](code/chapter76/defense_evaluation_visualization.py)
# - [Customizing adversarial attack and defense visualizations](code/chapter76/customizing_adversarial_attack_defense_visualizations.py)
#
# ## Chapter 77: Visualizing Quantum Circuits
# - [Plotting quantum circuit diagrams](code/chapter77/plotting_quantum_circuit_diagrams.py)
# - [Visualizing qubit states and measurements](code/chapter77/visualizing_qubit_states_measurements.py)
# - [Interactive quantum circuit visualization](code/chapter77/interactive_quantum_circuit_visualization.py)
# - [Customizing quantum circuit visualizations](code/chapter77/customizing_quantum_circuit_visualizations.py)
#
# ## Chapter 78: Visualizing Reinforcement Learning
# - [Plotting reward curves and learning progress](code/chapter78/plotting_reward_curves_learning_progress.py)
# - [Visualizing value functions and policies](code/chapter78/visualizing_value_functions_policies.py)
# - [Interactive reinforcement learning visualizations](code/chapter78/interactive_reinforcement_learning_visualizations.py)
# - [Customizing reinforcement learning visualizations](code/chapter78/customizing_reinforcement_learning_visualizations.py)
#
# ## Chapter 79: Visualizing Bayesian Inference
# - [Plotting posterior distributions](code/chapter79/plotting_posterior_distributions.py)
# - [Visualizing uncertainty and credible intervals](code/chapter79/visualizing_uncertainty_credible_intervals.py)
# - [Trace plots and convergence diagnostics](code/chapter79/trace_plots_convergence_diagnostics.py)
# - [Customizing Bayesian inference visualizations](code/chapter79/customizing_bayesian_inference_visualizations.py)
#
# ## Chapter 80: Visualizing Hyperparameter Optimization
# - [Plotting hyperparameter search spaces](code/chapter80/plotting_hyperparameter_search_spaces.py)
# - [Visualizing search progress and evaluations](code/chapter80/visualizing_search_progress_evaluations.py)
# - [Parallel coordinate plots](code/chapter80/parallel_coordinate_plots.py)
# - [Customizing hyperparameter optimization visualizations](code/chapter80/customizing_hyperparameter_optimization_visualizations.py)
#
# ## Chapter 81: Visualizing Active Learning
# - [Plotting uncertainty and informativeness measures](code/chapter81/plotting_uncertainty_informativeness_measures.py)
# - [Visualizing data selection and labeling process](code/chapter81/visualizing_data_selection_labeling_process.py)
# - [Interactive active learning visualizations](code/chapter81/interactive_active_learning_visualizations.py)
# - [Customizing active learning visualizations](code/chapter81/customizing_active_learning_visualizations.py)
#
# ## Chapter 82: Visualizing Explainable AI
# - [Plotting feature importance and contributions](code/chapter82/plotting_feature_importance_contributions.py)
# - [Visualizing rule-based explanations](code/chapter82/visualizing_rule_based_explanations.py)
# - [Interactive explainable AI visualizations](code/chapter82/interactive_explainable_ai_visualizations.py)
# - [Customizing explainable AI visualizations](code/chapter82/customizing_explainable_ai_visualizations.py)
#
# ## Chapter 83: Visualizing Transfer Learning and Domain Adaptation
# - [Plotting feature representations and transferability](code/chapter83/plotting_feature_representations_transferability.py)
# - [Visualizing domain shift and adaptation process](code/chapter83/visualizing_domain_shift_adaptation_process.py)
# - [Interactive transfer learning visualizations](code/chapter83/interactive_transfer_learning_visualizations.py)
# - [Customizing transfer learning visualizations](code/chapter83/customizing_transfer_learning_visualizations.py)
#
# ## Chapter 84: Visualizing Neural Architecture Interpretability
# - [Plotting neuron activations and responses](code/chapter84/plotting_neuron_activations_responses.py)
# - [Visualizing network attention and saliency maps](code/chapter84/visualizing_network_attention_saliency_maps.py)
# - [Interactive neural architecture interpretability visualizations](code/chapter84/interactive_neural_architecture_interpretability_visualizations.py)
# - [Customizing interpretability visualizations](code/chapter84/customizing_interpretability_visualizations.py)
#
# ## Chapter 85: Visualizing Uncertainty in Time Series Forecasting
# - [Plotting prediction intervals and quantiles](code/chapter85/plotting_prediction_intervals_quantiles.py)
# - [Visualizing forecast error distributions over time](code/chapter85/visualizing_forecast_error_distributions_over_time.py)
# - [Uncertainty decomposition and contribution plots](code/chapter85/uncertainty_decomposition_contribution_plots.py)
# - [Customizing uncertainty visualizations in time series forecasting](code/chapter85/customizing_uncertainty_visualizations_time_series_forecasting.py)
#
# ## Chapter 86: Visualizing Meta-Learning
# - [Plotting meta-learning progress and performance](code/chapter86/plotting_meta_learning_progress_performance.py)
# - [Visualizing meta-feature representations](code/chapter86/visualizing_meta_feature_representations.py)
# - [Interactive meta-learning visualizations](code/chapter86/interactive_meta_learning_visualizations.py)
# - [Customizing meta-learning visualizations](code/chapter86/customizing_meta_learning_visualizations.py)
#
# ## Chapter 87: Visualizing Anomaly Detection
# - [Plotting anomaly scores and thresholds over time](code/chapter87/plotting_anomaly_scores_thresholds_over_time.py)
# - [Visualizing anomaly detection results](code/chapter87/visualizing_anomaly_detection_results.py)
# - [Interactive anomaly detection visualizations](code/chapter87/interactive_anomaly_detection_visualizations.py)
# - [Customizing anomaly detection visualizations](code/chapter87/customizing_anomaly_detection_visualizations.py)
#
# ## Chapter 88: Visualizing Explainability in Recommendation Systems
# - [Plotting user-item interactions and explanations](code/chapter88/plotting_user_item_interactions_explanations.py)
# - [Visualizing recommendation explanations](code/chapter88/visualizing_recommendation_explanations.py)
# - [Interactive explainability visualizations in recommendation systems](code/chapter88/interactive_explainability_visualizations_recommendation_systems.py)
# - [Customizing explainability visualizations in recommendation systems](code/chapter88/customizing_explainability_visualizations_recommendation_systems.py)
#
# ## Chapter 89: Visualizing Uncertainty in Reinforcement Learning
# - [Plotting value uncertainty and exploration rates](code/chapter89/plotting_value_uncertainty_exploration_rates.py)
# - [Visualizing policy uncertainty and exploration-exploitation trade-offs](code/chapter89/visualizing_policy_uncertainty_exploration_tradeoffs.py)
# - [Interactive uncertainty visualizations in reinforcement learning](code/chapter89/interactive_uncertainty_visualizations_reinforcement_learning.py)
# - [Customizing uncertainty visualizations in reinforcement learning](code/chapter89/customizing_uncertainty_visualizations_reinforcement_learning.py)
#
# ## Chapter 90: Visualizing Federated Learning
# - [Plotting model updates and convergence](code/chapter90/plotting_model_updates_convergence.py)
# - [Visualizing distributed data sources](code/chapter90/visualizing_distributed_data_sources.py)
# - [Interactive federated learning visualizations](code/chapter90/interactive_federated_learning_visualizations.py)
# - [Customizing federated learning visualizations](code/chapter90/customizing_federated_learning_visualizations.py)

# %% [markdown]
# ## Chapter 91: Visualizing Graph Neural Networks
# - [Plotting graph structure and node features](code/chapter91/plotting_graph_structure_node_features.py)
# - [Visualizing graph convolutions and message passing](code/chapter91/visualizing_graph_convolutions_message_passing.py)
# - [Interactive graph neural network visualizations](code/chapter91/interactive_graph_neural_network_visualizations.py)
# - [Customizing graph neural network visualizations](code/chapter91/customizing_graph_neural_network_visualizations.py)
#
# ## Chapter 92: Visualizing Time Series Anomaly Detection
# - [Plotting anomaly scores and thresholds in time series](code/chapter92/plotting_anomaly_scores_thresholds_time_series.py)
# - [Visualizing detected anomalies in time series](code/chapter92/visualizing_detected_anomalies_time_series.py)
# - [Interactive anomaly detection visualizations in time series](code/chapter92/interactive_anomaly_detection_visualizations_time_series.py)
# - [Customizing anomaly detection visualizations in time series](code/chapter92/customizing_anomaly_detection_visualizations_time_series.py)
#
# ## Chapter 93: Visualizing Generative Adversarial Networks (GANs) in Computer Vision
# - [Plotting generated samples from GANs in computer vision](code/chapter93/plotting_generated_samples_gans_computer_vision.py)
# - [Visualizing latent space interpolations and transformations](code/chapter93/visualizing_latent_space_interpolations_transformations.py)
# - [Interactive GAN visualization in computer vision](code/chapter93/interactive_gan_visualization_computer_vision.py)
# - [Customizing GAN visualizations in computer vision](code/chapter93/customizing_gan_visualizations_computer_vision.py)
#
# ## Chapter 94: Visualizing Word Sense Disambiguation
# - [Plotting word sense representations and embeddings](code/chapter94/plotting_word_sense_representations_embeddings.py)
# - [Visualizing sense clusters and similarities](code/chapter94/visualizing_sense_clusters_similarities.py)
# - [Interactive word sense disambiguation visualizations](code/chapter94/interactive_word_sense_disambiguation_visualizations.py)
# - [Customizing word sense disambiguation visualizations](code/chapter94/customizing_word_sense_disambiguation_visualizations.py)
#
# ## Chapter 95: Visualizing Causal Inference
# - [Plotting causal graphs and relationships](code/chapter95/plotting_causal_graphs_relationships.py)
# - [Visualizing causal effects and interventions](code/chapter95/visualizing_causal_effects_interventions.py)
# - [Interactive causal inference visualizations](code/chapter95/interactive_causal_inference_visualizations.py)
# - [Customizing causal inference visualizations](code/chapter95/customizing_causal_inference_visualizations.py)
#
# ## Chapter 96: Visualizing Self-Supervised Learning
# - [Plotting self-supervised learning objectives and tasks](code/chapter96/plotting_self_supervised_learning_objectives_tasks.py)
# - [Visualizing learned representations](code/chapter96/visualizing_learned_representations.py)
# - [Interactive self-supervised learning visualizations](code/chapter96/interactive_self_supervised_learning_visualizations.py)
# - [Customizing self-supervised learning visualizations](code/chapter96/customizing_self_supervised_learning_visualizations.py)
#
# ## Chapter 97: Visualizing Meta-Learning in Reinforcement Learning
# - [Plotting meta-learning progress and performance in reinforcement learning](code/chapter97/plotting_meta_learning_progress_performance_reinforcement_learning.py)
# - [Visualizing meta-learned policies and adaptations](code/chapter97/visualizing_meta_learned_policies_adaptations.py)
# - [Interactive meta-learning visualizations in reinforcement learning](code/chapter97/interactive_meta_learning_visualizations_reinforcement_learning.py)
# - [Customizing meta-learning visualizations in reinforcement learning](code/chapter97/customizing_meta_learning_visualizations_reinforcement_learning.py)
#
# ## Chapter 98: Visualizing Active Learning in Computer Vision
# - [Plotting uncertainty and informativeness in active learning](code/chapter98/plotting_uncertainty_informativeness_active_learning.py)
# - [Visualizing active learning sample selection and labeling](code/chapter98/visualizing_active_learning_sample_selection_labeling.py)
# - [Interactive active learning visualizations in computer vision](code/chapter98/interactive_active_learning_visualizations_computer_vision.py)
# - [Customizing active learning visualizations in computer vision](code/chapter98/customizing_active_learning_visualizations_computer_vision.py)
#
# ## Chapter 99: Visualizing Unsupervised Learning in Computer Vision
# - [Plotting unsupervised learning objectives and representations](code/chapter99/plotting_unsupervised_learning_objectives_representations.py)
# - [Visualizing learned feature spaces and clusters](code/chapter99/visualizing_learned_feature_spaces_clusters.py)
# - [Interactive unsupervised learning visualizations in computer vision](code/chapter99/interactive_unsupervised_learning_visualizations_computer_vision.py)
# - [Customizing unsupervised learning visualizations in computer vision](code/chapter99/customizing_unsupervised_learning_visualizations_computer_vision.py)
#
# ## Chapter 100: Advanced Visualization Techniques and Future Trends
# - [Advanced data visualization techniques and libraries](code/chapter100/advanced_data_visualization_techniques_libraries.py)
# - [Visualization in augmented reality (AR) and virtual reality (VR)](code/chapter100/ar_vr.py)

# %% [markdown]
# # Chapter 1: Introduction to Matplotlib
#
# ## Section 1.1: What is Matplotlib?
#
# #### Matplotlib is a powerful data visualization library in Python that allows users to create high-quality plots, charts, and figures. It provides a flexible and comprehensive set of tools for creating various types of visualizations, making it a popular choice among data scientists, analysts, and researchers. Matplotlib can be used to generate a wide range of plots, from simple line plots to complex 3D visualizations, and it offers extensive customization options to tailor the appearance of the plots to suit specific needs.
#
# ## Section 1.2: Installing Matplotlib
#
# #### Before getting started with Matplotlib, it is essential to have it installed on your system. Matplotlib can be easily installed using the pip package manager, which comes pre-installed with Python. Open a command prompt or terminal and run the following command to install Matplotlib:
#
# ```python
#
# pip install matplotlib
# ```
#
# #### Once the installation is complete, you can import Matplotlib in your Python scripts or notebooks by using the following import statement:
#
# ```python
# import matplotlib.pyplot as plt
#
# ```
#
# ## Section 1.3: Basic plotting with Matplotlib
#
# #### Matplotlib provides a simple and intuitive interface for creating basic plots. Let's start by creating a simple line plot to visualize a set of data points. Consider the following example:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Simple Line Plot')

# Display the plot
plt.show()

# %% [markdown]
# #### In this example, we import the necessary Matplotlib module (pyplot) and create a figure and axes using the subplots() function. Then, we use the plot() method of the axes object (ax) to plot the data points. Finally, we set the labels and title of the plot using the set_xlabel(), set_ylabel(), and set_title() methods, respectively. The plt.show() function is called to display the plot.
#
# ## Section 1.4: Anatomy of a Matplotlib figure with example data and figures
#
# #### To understand the structure of a Matplotlib figure, let's explore the different components using an example. Consider the following code snippet:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate example data
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y1, label='Sin(x)')
ax.plot(x, y2, label='Cos(x)')

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Trigonometric Functions')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### In this example, we first import the necessary modules (matplotlib.pyplot and numpy) and generate example data using the linspace() function from NumPy. We create a figure and axes using the subplots() function. Then, we plot the data by calling the plot() method on the axes object (ax) multiple times. Each plot() call corresponds to a different line in the plot. We set the labels and title using the appropriate methods, and add a legend to differentiate between the plotted lines. Finally, we display the plot using plt.show().
#
# ### The resulting figure consists of several key components:
#
# #### **figure** : The entire area where the plot and its elements are displayed. It serves as the top-level container for all plot elements.
#
# #### **Axes** : The region within the figure where the actual plot is drawn. It includes the coordinate system, ticks, labels, and other graphical elements.
#
# #### **Data points and lines** : The actual data being plotted. In this example, the sine and cosine functions are plotted as lines.
#
# #### **Labels and title** : The text elements that provide information about the plot, such as axis labels and the plot's title.
#
# #### **Legend** : A box that provides a key to interpret the plotted lines or markers.
#
# #### Understanding the anatomy of a Matplotlib figure helps in customizing and manipulating individual components to create visually appealing and informative plots.
#
# #### This chapter provided an introduction to Matplotlib, covering its definition, installation process, and basic plotting techniques. Additionally, it explored the anatomy of a Matplotlib figure using an example, highlighting the key components involved in creating plots. This foundation will serve as a basis for exploring more advanced topics and techniques in subsequent chapters.

# %% [markdown]
# # Chapter 2: Line Plots
#
# ## Section 2.1: Creating a simple line plot
#
# #### One of the most common types of plots is a line plot, which is useful for visualizing the relationship between two variables. Matplotlib provides a straightforward way to create line plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the data as a line plot
ax.plot(x, y)

# Display the plot
plt.show()

# %% [markdown]
# #### In this example, we define two lists, x and y, which represent the x and y coordinates of the data points, respectively. We create a figure and axes using subplots(). Then, we use the plot() method of the axes object (ax) to plot the data as a line plot. Finally, we display the plot using plt.show().
#
# ## Section 2.2: Customizing line styles and colors
#
# #### Matplotlib allows you to customize the appearance of line plots by specifying different line styles and colors. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the data with a dashed red line
ax.plot(x, y, linestyle='--', color='red')

# Display the plot
plt.show()

# %% [markdown]
# #### In this modified example, we use the linestyle parameter of the plot() method to specify a dashed line ('--') and the color parameter to set the line color to red ('red'). You can explore other line styles and colors provided by Matplotlib to suit your needs.
#
# ## Section 2.3: Adding labels and titles
#
# #### Line plots become more informative when you add labels to the axes and a title to the plot. Let's enhance the previous example with labels and a title:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the data with labels and a title
ax.plot(x, y)
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Line Plot Example')

# Display the plot
plt.show()

# %% [markdown]
# #### in this updated example, we use the set_xlabel(), set_ylabel(), and set_title() methods of the axes object (ax) to set the x-axis label, y-axis label, and plot title, respectively.
#
# ## Section 2.4: Plotting multiple lines
#
# #### Matplotlib allows you to plot multiple lines on the same plot, which is useful for comparing multiple datasets or visualizing different aspects of the same dataset. Let's modify the previous example to include multiple lines:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

# Create a figure and axes
fig, ax = plt.subplots()

# Plot multiple lines
ax.plot(x, y1, label='Line 1')
ax.plot(x, y2, label='Line 2')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### in this updated example, we define two sets of y-coordinates (y1 and y2) to represent two different lines. We call the plot() method twice, each time with different y-coordinates, to plot the two lines. We use the label parameter in the plot() method to provide labels for the lines. Finally, we add a legend to differentiate between the two lines using the legend() method.
#
# #### By leveraging these techniques, you can create visually appealing and informative line plots using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your line plots.

# %% [markdown]
# # Chapter 3: Scatter Plots
#
# ## Section 3.1: Creating a basic scatter plot
#
# #### Scatter plots are useful for visualizing the relationship between two continuous variables. Matplotlib provides the scatter() function to create scatter plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(x, y)

# Display the plot
plt.show()

# %% [markdown]
# #### In this example, we define two lists, x and y, which represent the x and y coordinates of the data points, respectively. We create a figure and axes using subplots(). Then, we use the scatter() function of the axes object (ax) to create a scatter plot of the data points. Finally, we display the plot using plt.show().
#
# ## Section 3.2: Customizing marker styles and sizes
#
# #### Matplotlib allows you to customize the appearance of scatter plots by specifying different marker styles and sizes. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot with customized markers
ax.scatter(x, y, marker='s', s=100, c='red')

# Display the plot
plt.show()

# %% [markdown]
# #### In this modified example, we use the marker parameter of the scatter() function to specify square markers ('s') and the s parameter to set the marker size to 100. Additionally, we use the c parameter to set the marker color to red ('red'). You can explore different marker styles, sizes, and colors provided by Matplotlib to suit your requirements.
#
# ## Section 3.3: Adding labels and titles
#
# #### To provide more context and information, it is important to add labels to the axes and a title to the plot. Let's enhance the previous example with labels and a title:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot with labels and a title
ax.scatter(x, y)
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Scatter Plot Example')

# Display the plot
plt.show()

# %% [markdown]
# #### In this updated example, we use the set_xlabel(), set_ylabel(), and set_title() methods of the axes object (ax) to set the x-axis label, y-axis label, and plot title, respectively.
#
# ## Section 3.4: Highlighting specific data points
#
# #### Scatter plots can be further enhanced by highlighting specific data points or groups of data points. Let's modify the previous example to highlight certain points:

# %%
import matplotlib.pyplot as plt

# Data points
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot with highlighted data points
ax.scatter(x, y, c='blue')
ax.scatter([3], [6], c='red', s=100, label='Highlighted Point')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### In this updated example, we first create a scatter plot with all the data points in blue. Then, we use another scatter() function call to add a specific data point at coordinates (3, 6) and color it red. We also customize the size of the highlighted point with the s parameter and provide a label for it. Finally, we add a legend to indicate the highlighted point using the legend() method.
#
# ##### By leveraging these techniques, you can create visually appealing and informative scatter plots using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your scatter plots.

# %% [markdown]
# # Chapter 4: Bar Plots
#
# ## Section 4.1: Creating vertical and horizontal bar plots
#
# #### Bar plots are commonly used to compare categorical data or show the distribution of a variable across different categories. Matplotlib provides the bar() function to create vertical bar plots and the barh() function for horizontal bar plots. Let's explore examples for both types:
#
# ### Vertical Bar Plot:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 15, 7, 12, 9]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a vertical bar plot
ax.bar(categories, values)

# Display the plot
plt.show()

# %% [markdown]
# ### Horizontal Bar Plot:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 15, 7, 12, 9]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a horizontal bar plot
ax.barh(categories, values)

# Display the plot
plt.show()

# %% [markdown]
# #### In both examples, we define a list of categories and a corresponding list of values. We create a figure and axes using subplots(). Then, we use either the bar() function or the barh() function of the axes object (ax) to create a vertical or horizontal bar plot, respectively. The categories are used as the x-axis (vertical bar plot) or y-axis (horizontal bar plot), and the values determine the height or width of the bars.
#
# ## Section 4.2: Customizing bar colors and widths
#
# #### Matplotlib allows you to customize the appearance of bar plots by specifying different colors and widths for the bars. Let's modify the previous vertical bar plot example to demonstrate this:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 15, 7, 12, 9]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a vertical bar plot with customized colors and widths
ax.bar(categories, values, color='orange', width=0.6)

# Display the plot
plt.show()

# %% [markdown]
# #### In this modified example, we use the color parameter of the bar() function to set the color of the bars to orange ('orange'). Additionally, we use the width parameter to customize the width of the bars. You can experiment with different colors and widths to achieve the desired visual effect.
#
# ## Section 4.3: Grouped and stacked bar plots
#
# #### Matplotlib allows you to create grouped and stacked bar plots, which are useful for comparing multiple variables or subgroups within each category. Let's explore examples for both types:
#
# ### Grouped Bar Plot:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values1 = [10, 15, 7, 12, 9]
values2 = [8, 11, 9, 7, 15]

# Create a figure and axes
fig, ax = plt.subplots()

# Set the width of each bar
width = 0.35

# Create grouped bar plot
ax.bar(np.arange(len(categories)), values1, width, label='Group 1')
ax.bar(np.arange(len(categories)) + width, values2, width, label='Group 2')

# Set x-axis tick labels
ax.set_xticks(np.arange(len(categories)) + width / 2)
ax.set_xticklabels(categories)

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### Stacked Bar Plot:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values1 = [10, 15, 7, 12, 9]
values2 = [8, 11, 9, 7, 15]

# Create a figure and axes
fig, ax = plt.subplots()

# Create stacked bar plot
ax.bar(categories, values1, label='Group 1')
ax.bar(categories, values2, bottom=values1, label='Group 2')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### In the grouped bar plot example, we create two sets of values (values1 and values2) corresponding to two different groups. We use the bar() function twice, shifting the bars for the second group horizontally using np.arange(len(categories)) + width, where width is the width of each bar. We also set the x-axis tick labels using set_xticks() and set_xticklabels().
#
# #### In the stacked bar plot example, we use the bottom parameter of the second bar() function to specify the values of the first group, resulting in stacked bars. The bottom parameter specifies the starting height of the bars for the second group.
#
# ## Section 4.4: Adding error bars
#
# #### Error bars are often used to indicate the variability or uncertainty associated with each bar in a bar plot. Matplotlib allows you to add error bars using the errorbar() function. Let's modify the previous vertical bar plot example to include error bars:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 15, 7, 12, 9]
errors = [1, 2, 1.5, 0.5, 2]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a vertical bar plot with error bars
ax.bar(categories, values, yerr=errors, capsize=4)

# Display the plot
plt.show()

# %% [markdown]
# #### In this modified example, we define an additional list, errors, that represents the error associated with each bar. We use the yerr parameter of the bar() function to specify the error values. Additionally, we set the capsize parameter to control the size of the error bar caps. You can customize the error bars further by exploring other available parameters provided by Matplotlib.
#
# #### By utilizing these techniques, you can create visually appealing and informative bar plots using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your bar plots.

# %% [markdown]
# # Chapter 5: Histograms
#
# ## Section 5.1: Creating a histogram
#
# #### Histograms are useful for visualizing the distribution of continuous data by dividing it into bins and displaying the frequency or count of data points within each bin. Matplotlib provides the hist() function to create histograms. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.randn(1000)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a histogram
ax.hist(data)

# Display the plot
plt.show()

# %% [markdown]
# #### In this example, we generate random data using NumPy's random.randn() function to create an array of 1000 normally distributed data points. We create a figure and axes using subplots(). Then, we use the hist() function of the axes object (ax) to create a histogram of the data. Finally, we display the plot using plt.show().
#
# ## Section 5.2: Customizing bin sizes and colors
#
# #### Matplotlib allows you to customize the appearance of histograms by specifying different bin sizes and colors. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.randn(1000)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a histogram with customized bin sizes and colors
ax.hist(data, bins=30, color='skyblue')

# Display the plot
plt.show()

# %% [markdown]
# #### In this modified example, we use the bins parameter of the hist() function to specify the number of bins in the histogram (in this case, 30). Additionally, we use the color parameter to set the color of the bars to sky blue ('skyblue'). You can experiment with different bin sizes and colors to achieve the desired visual effect.
#
# ## Section 5.3: Overlaying multiple histograms
#
# #### Matplotlib allows you to overlay multiple histograms on the same plot, making it easier to compare distributions. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(2, 1, 1000)

# Create a figure and axes
fig, ax = plt.subplots()

# Create histograms for both datasets
ax.hist(data1, bins=30, alpha=0.5, label='Data 1')
ax.hist(data2, bins=30, alpha=0.5, label='Data 2')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### In this example, we generate two sets of random data using NumPy's random.normal() function to create arrays of 1000 data points each, following different normal distributions. We create a figure and axes using subplots(). Then, we use the hist() function twice to create histograms for both datasets. We use the alpha parameter to control the transparency of the bars, resulting in overlapping histograms. We also provide labels for each histogram using the label parameter. Finally, we add a legend to differentiate between the two datasets.
#
# ## Section 5.4: Probability density estimation
#
# #### In addition to showing the frequency or count of data points, histograms can also provide an estimate of the underlying probability density function (PDF) of the data. Matplotlib supports probability density estimation using the density parameter of the hist() function. Let's modify the previous example to include probability density estimation:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(2, 1, 1000)

# Create a figure and axes
fig, ax = plt.subplots()

# Create histograms with probability density estimation
ax.hist(data1, bins=30, density=True, alpha=0.5, label='Data 1')
ax.hist(data2, bins=30, density=True, alpha=0.5, label='Data 2')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### In this modified example, we use the density=True parameter in both hist() function calls to enable probability density estimation. This rescales the histogram bars to represent the estimated probability density, allowing for a fair comparison between datasets with different sample sizes. Keep in mind that the area under each histogram bar represents the probability density, not the count or frequency.
#
# #### By utilizing these techniques, you can create visually appealing and informative histograms using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your histogram visualizations.

# %% [markdown]
# Chapter 6: Pie Charts
#
# Section 6.1: Creating a basic pie chart
#
# Pie charts are useful for displaying the proportion of different categories in a dataset. Matplotlib provides the pie() function to create pie charts. Let's consider an example:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [15, 30, 25, 10, 20]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a basic pie chart
ax.pie(values, labels=categories)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we define a list of categories and a corresponding list of values. We create a figure and axes using subplots(). Then, we use the pie() function of the axes object (ax) to create a basic pie chart, providing the values and labels as arguments. Finally, we display the plot using plt.show().
#
# Section 6.2: Exploding and highlighting slices
#
# Matplotlib allows you to highlight specific slices in a pie chart by "exploding" them or using custom colors. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [15, 30, 25, 10, 20]
explode = [0, 0.1, 0, 0, 0]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a pie chart with exploded slices
ax.pie(values, labels=categories, explode=explode)

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we define an additional list, explode, that specifies the extent to which each slice is separated from the center of the pie. A value of 0 means no separation, while a non-zero value "explodes" the corresponding slice. By setting explode[1] to 0.1, we separate the second slice (corresponding to category 'B') from the center. You can adjust the explode list to highlight specific slices as desired.
#
# Section 6.3: Adding a legend and labels
#
# To provide more context and information, it is important to add a legend to identify the categories and labels to display the percentage or values associated with each slice. Let's enhance the previous example with a legend and labels:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [15, 30, 25, 10, 20]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a pie chart with a legend and labels
ax.pie(values, labels=categories, autopct='%1.1f%%')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# In this updated example, we use the autopct parameter in the pie() function to format the labels on the pie chart slices as percentages ('%1.1f%%'). We also call the legend() method to add a legend that identifies the categories. The legend entries are automatically generated from the labels argument provided to the pie() function.
#
# Section 6.4: Donut charts
#
# A donut chart is a variant of a pie chart with a hole in the center. Matplotlib can be used to create donut charts by drawing an additional white circle in the center. Let's modify the previous example to create a donut chart:

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values = [15, 30, 25, 10, 20]

# Create a figure and axes
fig, ax = plt.subplots()

# Create a donut chart
ax.pie(values, labels=categories, wedgeprops=dict(width=0.4), autopct='%1.1f%%')

# Add a white circle in the center
center_circle = plt.Circle((0, 0), 0.6, color='white')
ax.add_artist(center_circle)

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use the wedgeprops parameter in the pie() function to specify the width of the pie slices using dict(width=0.4). A smaller width creates a larger hole in the center, resulting in a donut chart. We create a white circle using the Circle() function and add it to the axes using add_artist() to complete the donut appearance.
#
# By utilizing these techniques, you can create visually appealing and informative pie charts, including exploded slices, legends, labels, and donut charts, using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your pie chart visualizations.

# %% [markdown]
# Chapter 7: Box Plots
#
# Section 7.1: Creating a box plot
#
# Box plots, also known as whisker plots, are useful for visualizing the distribution of a continuous variable across different categories or groups. Matplotlib provides the boxplot() function to create box plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(2, 1, 100)
data3 = np.random.normal(5, 1, 100)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a box plot
ax.boxplot([data1, data2, data3])

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate three sets of random data using NumPy's random.normal() function to create arrays of 100 data points each, following different normal distributions. We create a figure and axes using subplots(). Then, we use the boxplot() function of the axes object (ax) to create a box plot, providing a list of arrays as the argument. Each array represents the data points for a specific category or group. Finally, we display the plot using plt.show().
#
# Section 7.2: Customizing whiskers and outliers
#
# Matplotlib allows you to customize the appearance of box plots by specifying different whiskers, outliers, and other properties. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(2, 1, 100)
data3 = np.random.normal(5, 1, 100)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a box plot with customized whiskers and outliers
ax.boxplot([data1, data2, data3], notch=True, whis=1.5, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 5})

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use several additional parameters in the boxplot() function to customize the appearance of the whiskers and outliers. We set notch=True to create a notched box plot, which displays a confidence interval around the median. We adjust the whis parameter to control the length of the whiskers (1.5 times the interquartile range by default). We use the flierprops parameter to specify the properties of the outliers, including the marker style, face color, and size.
#
# Section 7.3: Grouped and stacked box plots
#
# Matplotlib allows you to create grouped and stacked box plots, which are useful for comparing distributions across multiple categories or groups. Let's explore examples for both types:
#
# Grouped Box Plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(2, 1, 100)
data3 = np.random.normal(5, 1, 100)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a grouped box plot
ax.boxplot([data1, data2, data3], positions=[1, 2, 3])

# Set x-axis tick labels
ax.set_xticks([1, 2, 3])
ax.set_xticklabels(['Group 1', 'Group 2', 'Group 3'])

# Display the plot
plt.show()

# %% [markdown]
# Stacked Box Plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(2, 1, 100)
data3 = np.random.normal(5, 1, 100)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a stacked box plot
ax.boxplot([data1, data2, data3], vert=False)

# Set y-axis tick labels
ax.set_yticklabels(['Group 1', 'Group 2', 'Group 3'])

# Display the plot
plt.show()

# %% [markdown]
# In the grouped box plot example, we use the positions parameter to specify the x-axis positions of the box plots. By default, the box plots are evenly spaced. We set the x-axis tick locations and labels using set_xticks() and set_xticklabels().
#
# In the stacked box plot example, we set the vert parameter to False to create a horizontal stacked box plot. We adjust the y-axis tick labels using set_yticklabels().
#
# Section 7.4: Violin plots
#
# Violin plots combine box plots with kernel density estimation to provide a more detailed view of the data distribution. Matplotlib allows you to create violin plots using the violinplot() function. Let's modify the previous example to create a violin plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(2, 1, 100)
data3 = np.random.normal(5, 1, 100)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a violin plot
ax.violinplot([data1, data2, data3])

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use the violinplot() function instead of boxplot() to create a violin plot. The violin plots display the distribution of the data using mirrored kernel density estimation on each side of the box plot. The width of the violin represents the data density at different values.

# %% [markdown]
# Chapter 8: Polar Plots
#
# Section 8.1: Creating polar plots
#
# Polar plots, also known as radial plots, are useful for visualizing data in a circular coordinate system. Matplotlib provides the polar() function to create polar plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
theta = np.linspace(0, 2 * np.pi, 100)
r = np.cos(3 * theta)

# Create a figure and axes in polar projection
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

# Create a polar plot
ax.plot(theta, r)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we define an array theta that represents the angular coordinates and an array r that represents the radial coordinates. We create a figure and axes using subplots() with the projection parameter set to 'polar' to create a polar projection. Then, we use the plot() function of the axes object (ax) to create a polar plot, providing theta and r as arguments. Finally, we display the plot using plt.show().
#
# Section 8.2: Customizing tick labels and gridlines
#
# Matplotlib allows you to customize the tick labels and gridlines in polar plots. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
theta = np.linspace(0, 2 * np.pi, 100)
r = np.cos(3 * theta)

# Create a figure and axes in polar projection
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

# Create a polar plot with customized tick labels and gridlines
ax.plot(theta, r)
ax.set_xticks(np.arange(0, 2 * np.pi, np.pi / 4))
ax.set_xticklabels(['0', '45', '90', '135', '180', '225', '270', '315'])
ax.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use the set_xticks() and set_xticklabels() methods of the axes object (ax) to customize the tick labels on the x-axis in radians. We set the x-tick locations to evenly spaced values between 0 and 2π and provide custom labels for each tick. We also use the grid() method to enable gridlines on the polar plot.
#
# Section 8.3: Adding multiple plots in polar coordinates
#
# Matplotlib allows you to add multiple plots in polar coordinates on the same figure, enabling comparisons between different datasets or aspects. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
theta = np.linspace(0, 2 * np.pi, 100)
r1 = np.cos(3 * theta)
r2 = np.sin(2 * theta)

# Create a figure and axes in polar projection
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

# Create multiple plots in polar coordinates
ax.plot(theta, r1, label='Plot 1')
ax.plot(theta, r2, label='Plot 2')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we define two arrays, r1 and r2, that represent the radial coordinates for two different plots. We create a figure and axes using subplots() with the projection parameter set to 'polar'. Then, we use the plot() function twice to create two different plots in polar coordinates, each with its own label. We add a legend to differentiate between the plots using the legend() method.
#
# Section 8.4: Wind rose plots
#
# A wind rose plot is a specific type of polar plot used to visualize wind direction and speed data. Matplotlib can be used to create wind rose plots by binning the wind direction data and representing the wind speed using color or other visual cues. Let's explore an example:

# %% [markdown]
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Generate random wind direction and speed data
# np.random.seed(0)
# num_points = 100
# directions = np.random.uniform(0, 360, num_points)
# speeds = np.random.uniform(0, 10, num_points)
#
# # Create a figure and axes in polar projection
# fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
#
# # Create a wind rose plot
# ax.hist(directions, bins=36, range=(0, 360), weights=speeds, color='skyblue')
#
# # Set x-axis tick labels
# ax.set_xticks(np.arange(0, 2 * np.pi, np.pi / 6))
# ax.set_xticklabels(['N', 'NE', 'E', 'SE', 'S', 'SW', 'W', 'NW'])
#
# # Set y-axis label
# ax.set_ylabel('Wind Speed (m/s)')
#
# #Display the plot
# plt.show()
# ```

# %% [markdown]
# In this example, we generate random wind direction and speed data using NumPy's random.uniform() function. The directions array represents the wind direction in degrees (0-360), and the speeds array represents the wind speed in meters per second. We create a figure and axes using subplots() with the projection parameter set to 'polar'. Then, we use the hist() function of the axes object (ax) to create a wind rose plot by binning the wind direction data and weighting each bin by the wind speed. We customize the x-axis tick labels to display the cardinal directions and set the y-axis label to indicate the wind speed.
#
# By utilizing these techniques, you can create visually appealing and informative polar plots, customize tick labels and gridlines, add multiple plots in polar coordinates, and create wind rose plots using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your polar plot visualizations.

# %% [markdown]
# Chapter 9: 3D Plots
#
# Section 9.1: Creating 3D scatter plots
#
# 3D scatter plots are useful for visualizing the relationship between three continuous variables. Matplotlib provides the scatter3D() function to create 3D scatter plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
x = np.random.randn(100)
y = np.random.randn(100)
z = np.random.randn(100)

# Create a figure and axes in 3D projection
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a 3D scatter plot
ax.scatter3D(x, y, z)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate three sets of random data using NumPy's random.randn() function to create arrays of 100 data points each. We create a figure using plt.figure() and an axes object using fig.add_subplot(111, projection='3d') to specify a 3D projection. Then, we use the scatter3D() function of the axes object (ax) to create a 3D scatter plot, providing x, y, and z as the coordinate variables. Finally, we display the plot using plt.show().
#
# Section 9.2: Surface plots
#
# Surface plots are useful for visualizing three-dimensional data on a continuous surface. Matplotlib provides the plot_surface() function to create surface plots. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data for the surface plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create a figure and axes in 3D projection
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a surface plot
ax.plot_surface(X, Y, Z, cmap='viridis')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate X and Y coordinate grids using np.meshgrid() based on the x and y arrays. We calculate Z values using a mathematical function (in this case, np.sin(np.sqrt(X**2 + Y**2))). We create a figure and axes in 3D projection. Then, we use the plot_surface() function of the axes object (ax) to create a surface plot, providing X, Y, and Z as the coordinate variables. We also specify the cmap parameter to set the colormap used for coloring the surface. Finally, we display the plot using plt.show().
#
# Section 9.3: Wireframe plots
#
# Wireframe plots are useful for visualizing three-dimensional data as a collection of lines connecting points on a surface. Matplotlib provides the plot_wireframe() function to create wireframe plots. Let's modify the previous example to create a wireframe plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data for the wireframe plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create a figure and axes in 3D projection
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a wireframe plot
ax.plot_wireframe(X, Y, Z)

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use the plot_wireframe() function instead of plot_surface() to create a wireframe plot. The function connects the points on the surface using lines, creating a grid-like representation of the data.
#
# Section 9.4: Contour plots
#
# Contour plots are useful for visualizing three-dimensional data by representing constant values on a two-dimensional plane. Matplotlib provides the contour() function to create contour plots. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data for the contour plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create a figure and axes in 3D projection
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a contour plot
ax.contour(X, Y, Z, levels=10, cmap='viridis')

# Display the plot
plt.show()

# %% [markdown]
# n this example, we use the contour() function to create a contour plot. We provide X, Y, and Z as the coordinate variables and set the levels parameter to specify the number of contour levels. The cmap parameter is used to set the colormap for the contour plot. By default, contour lines are drawn at the specified levels, representing the constant values of Z.

# %% [markdown]
# Chapter 10: Subplots
#
# Section 10.1: Creating subplots with subplot
#
# Subplots are useful for creating multiple plots within a single figure. Matplotlib provides the subplot() function to create subplots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure with two subplots
plt.subplot(2, 1, 1)  # 2 rows, 1 column, subplot 1
plt.plot(x, y1)
plt.title('Subplot 1')

plt.subplot(2, 1, 2)  # 2 rows, 1 column, subplot 2
plt.plot(x, y2)
plt.title('Subplot 2')

# Adjust subplot spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure with two subplots using plt.subplot(). The first argument specifies the number of rows, the second argument specifies the number of columns, and the third argument specifies the current subplot number. We plot y1 in the first subplot and y2 in the second subplot. We also set titles for each subplot using plt.title(). Finally, we use plt.tight_layout() to adjust the spacing between subplots, ensuring that the plot elements do not overlap. The resulting figure will have two vertically stacked subplots.
#
# Section 10.2: Grid of subplots with subplots
#
# Matplotlib also provides the subplots() function to create a grid of subplots. Let's modify the previous example to use subplots():

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

# Create a figure with a grid of subplots
fig, axs = plt.subplots(2, 2)

# Plot data in each subplot
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Subplot 1')

axs[0, 1].plot(x, y2)
axs[0, 1].set_title('Subplot 2')

axs[1, 0].plot(x, y3)
axs[1, 0].set_title('Subplot 3')

# Hide the last subplot
axs[1, 1].axis('off')

# Adjust subplot spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use plt.subplots() to create a figure with a grid of subplots. The function returns a figure object and a two-dimensional array of axes objects (axs). We plot the data in each subplot by accessing the appropriate axes object using indexing. We set titles for each subplot and adjust the subplot spacing using plt.tight_layout(). Additionally, we use axs[1, 1].axis('off') to hide the last subplot in the grid. The resulting figure will have three subplots arranged in a 2x2 grid.
#
# Section 10.3: Sharing axes between subplots
#
# Matplotlib allows you to share axes between subplots, which can be useful for comparing data or maintaining consistent scales. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure with two subplots sharing the x-axis
fig, axs = plt.subplots(2, 1, sharex=True)

# Plot data in each subplot
axs[0].plot(x, y1)
axs[0].set_title('Subplot 1')

axs[1].plot(x, y2)
axs[1].set_title('Subplot 2')

# Adjust subplot spacing
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use plt.subplots() to create a figure with two subplots. We set sharex=True to share the x-axis between the subplots. This ensures that the x-axis scale remains consistent across both subplots. We plot the data in each subplot and set titles as before. Finally, we adjust the subplot spacing using plt.tight_layout(). The resulting figure will have two vertically stacked subplots with a shared x-axis.
#
# Section 10.4: Creating insets and multiple axes
#
# Matplotlib allows you to create insets, which are additional smaller plots within a larger plot, and multiple axes, which are additional coordinate systems within a single figure. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure with an inset and multiple axes
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()  # Create a second y-axis

# Plot data on the main axes
ax1.plot(x, y1, 'b', label='Data 1')
ax1.set_xlabel('X')
ax1.set_ylabel('Y1')
ax1.legend()

# Create an inset on the main axes
inset_ax = ax1.inset_axes([0.1, 0.6, 0.3, 0.3])
inset_ax.plot(x, y2, 'r', label='Data 2')
inset_ax.set_xlabel('X')
inset_ax.set_ylabel('Y2')
inset_ax.legend()

# Plot data on the second y-axis
ax2.plot(x, y2, 'g', label='Data 2')
ax2.set_ylabel('Y2')
ax2.legend()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure with the main axes using plt.subplots(). We create a second y-axis using ax1.twinx() to plot additional data. We plot y1 on the main axes and y2 on the second y-axis. We set labels for the x-axis and each y-axis using ax1.set_xlabel(), ax1.set_ylabel(), and ax2.set_ylabel(). We also add legends to indicate the plotted data. Additionally, we create an inset on the main axes using ax1.inset_axes() and plot y2 on the inset axes. We adjust the position and size of the inset using the [left, bottom, width, height] coordinates. The resulting figure will display the main plot, the second y-axis plot, and an inset with its own plot.

# %% [markdown]
# Chapter 11: Annotations and Text
#
# Section 11.1: Adding text to plots
#
# Annotations and text are useful for providing additional information or labels in a plot. Matplotlib provides the text() function to add text to plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Add text
ax.text(2, 0.5, 'Text Example', fontsize=12, color='red')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot x and y using ax.plot(). We add text using ax.text(), specifying the x-coordinate, y-coordinate, text string, fontsize, and color. The text is positioned at (2, 0.5) on the plot. Finally, we display the plot using plt.show().
#
# Section 11.2: Annotations with arrows and lines
#
# Annotations with arrows and lines are useful for highlighting specific data points or relationships in a plot. Matplotlib provides the annotate() function to add annotations with arrows or lines. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Add annotation with an arrow
ax.annotate('Annotation Example', xy=(2, 0.5), xytext=(4, 0.8), arrowprops={'arrowstyle': '->'})

# Add annotation with a line
ax.annotate('Another Example', xy=(5, -0.5), xytext=(7, -0.7), arrowprops={'arrowstyle': '-', 'ls': '--'})

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot x and y using ax.plot(). We add an annotation with an arrow using ax.annotate(), specifying the text string, target coordinates (xy), text coordinates (xytext), and arrow properties (arrowprops). We use the '->' arrow style for the first annotation. We add another annotation with a line using the '-' arrow style and ls='--' for a dashed line. Finally, we display the plot using plt.show().
#
# Section 11.3: Adding mathematical expressions
#
# Matplotlib allows you to include mathematical expressions in text annotations and labels. You can use LaTeX syntax within the text by enclosing the expression with dollar signs. Let's modify the previous example to include a mathematical expression:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Add text with a mathematical expression
ax.text(2, 0.5, r'$y = \sin(x)$', fontsize=12, color='red')

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use r'$y = \sin(x)$' as the text string for the ax.text() function. The r prefix indicates a raw string, which allows us to use LaTeX syntax without escaping special characters. The expression r'$y = \sin(x)$' will be rendered as a mathematical equation in the plot.
#
# Section 11.4: Watermark and image annotations
#
# Matplotlib allows you to add watermarks or image annotations to plots by overlaying images. Let's explore an example:

# %% [markdown]
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Data
# x = np.linspace(0, 10, 100)
# y = np.sin(x)
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot data
# ax.plot(x, y)
#
# # Load and overlay an image
# img = plt.imread('watermark.png')
# ax.imshow(img, extent=(4, 6, -0.8, -0.6), alpha=0.5)
#
# # Display the plot
# plt.show()
# ```

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot x and y using ax.plot(). We load an image using plt.imread() and store it in the img variable. We overlay the image using ax.imshow(), specifying the extent to define the location and size of the image on the plot. The alpha parameter adjusts the transparency of the image. Finally, we display the plot using plt.show().

# %% [markdown]
# Chapter 12: Legends and Colorbars
#
# Section 12.1: Creating legends
#
# Legends are useful for providing a visual guide to the elements of a plot, such as different data series or plot types. Matplotlib provides the legend() function to create legends. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y1, label='Sin')
ax.plot(x, y2, label='Cos')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot y1 and y2 using ax.plot(), providing labels for each data series using the label parameter. We add a legend using ax.legend(), which automatically generates a legend based on the labels provided. Finally, we display the plot using plt.show().
#
# Section 12.2: Customizing legend appearance
#
# Matplotlib allows you to customize the appearance of legends by modifying various properties. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
line1, = ax.plot(x, y1, label='Sin')
line2, = ax.plot(x, y2, label='Cos')

# Add a legend with customized appearance
legend = ax.legend(handles=[line1, line2], loc='upper right', shadow=True, fancybox=True, title='Legend')
legend.get_title().set_fontsize('12')

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we assign the return values of ax.plot() to variables line1 and line2 to customize the legend appearance. We create a legend using ax.legend() and provide the handles parameter to specify the lines to be included in the legend. We set the loc parameter to 'upper right' to position the legend in the upper right corner. We enable a shadow effect using shadow=True and a rounded box using fancybox=True. We add a title to the legend using the title parameter and modify the title font size using legend.get_title().set_fontsize('12'). Finally, we display the plot using plt.show().
#
# Section 12.3: Colorbars for scalar plots
#
# Colorbars are useful for representing the mapping between colors and scalar values in a plot, such as heatmaps or contour plots. Matplotlib provides the colorbar() function to create colorbars. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.rand(10, 10)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a heatmap
heatmap = ax.imshow(data, cmap='hot')

# Add a colorbar
colorbar = plt.colorbar(heatmap)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data using NumPy's random.rand() function. We create a figure and axes using plt.subplots(). We create a heatmap using ax.imshow(), providing the data array and specifying the desired colormap ('hot' in this case). We add a colorbar using plt.colorbar(), which automatically generates a colorbar based on the colormap and data range. Finally, we display the plot using plt.show().
#
# Section 12.4: Color normalization and mapping
#
# Matplotlib allows you to customize the color normalization and mapping for scalar plots. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize, LogNorm

# Generate random data
np.random.seed(0)
data = np.random.rand(10, 10) * 1000

# Create a figure and axes
fig, ax = plt.subplots()

# Create a heatmap with customized color normalization and mapping
heatmap = ax.imshow(data, cmap='jet', norm=LogNorm(vmin=1, vmax=1000))

# Add a colorbar
colorbar = plt.colorbar(heatmap)

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we generate random data using NumPy's random.rand() function and scale it by 1000. We create a figure and axes using plt.subplots(). We create a heatmap using ax.imshow(), specifying the desired colormap ('jet' in this case). We also customize the color normalization and mapping by providing the norm parameter with LogNorm(vmin=1, vmax=1000), which maps the scalar values logarithmically between the specified minimum and maximum. Finally, we display the plot using plt.show().

# %% [markdown]
# Chapter 13: Ticks and Spines
#
# Section 13.1: Customizing tick locations and labels
#
# Ticks are the markers on the axes that indicate specific values. Matplotlib allows you to customize the tick locations and labels to suit your needs. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Customize tick locations and labels
ax.set_xticks([0, 2, 4, 6, 8, 10])
ax.set_xticklabels(['0', '2', '4', '6', '8', '10'])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticklabels(['-1', '-0.5', '0', '0.5', '1'])

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot x and y using ax.plot(). We customize the tick locations on the x-axis and y-axis using ax.set_xticks() and ax.set_yticks(), respectively, providing a list of tick positions. We also customize the tick labels using ax.set_xticklabels() and ax.set_yticklabels(), providing a list of corresponding labels. Finally, we display the plot using plt.show().
#
# Section 13.2: Setting tick formats
#
# Matplotlib allows you to customize the format of tick labels to control how values are displayed on the axes. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Customize tick formats
formatter = FuncFormatter(lambda x, pos: f'{x:.2f}')
ax.xaxis.set_major_formatter(formatter)
ax.yaxis.set_major_formatter(formatter)

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we use the FuncFormatter class from matplotlib.ticker to customize the tick formats. We define a lambda function that formats the tick value with two decimal places ('{x:.2f}'). We set the formatter for both the x-axis and y-axis using ax.xaxis.set_major_formatter() and ax.yaxis.set_major_formatter(), respectively. This ensures that the tick labels display the formatted values. Finally, we display the plot using plt.show().
#
# Section 13.3: Hiding and customizing spines
#
# Spines are the lines that connect the ticks on the axes. Matplotlib allows you to hide or customize the spines to control the appearance of the plot. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Hide spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Customize spines
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_color('red')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot x and y using ax.plot(). We hide the top and right spines using ax.spines['top'].set_visible(False) and ax.spines['right'].set_visible(False), respectively. We customize the bottom spine by setting its linewidth to 2 using ax.spines['bottom'].set_linewidth(2). We also customize the left spine by setting its color to red using ax.spines['left'].set_color('red'). Finally, we display the plot using plt.show().
#
# Section 13.4: Twin axes and logarithmic scales
#
# Matplotlib allows you to create twin axes, which share the same x-axis but have different y-axes. You can also use logarithmic scales to represent data with a wide range of values. Let's modify the previous example to demonstrate these features:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.exp(x)

# Create a figure and axes
fig, ax1 = plt.subplots()

# Plot data on the first axes
ax1.plot(x, y1, 'b')
ax1.set_ylabel('Sin(x)', color='b')
ax1.tick_params('y', colors='b')

# Create a twin axes sharing the x-axis
ax2 = ax1.twinx()

# Plot data on the second axes
ax2.plot(x, y2, 'r')
ax2.set_ylabel('Exp(x)', color='r')
ax2.tick_params('y', colors='r')

# Set logarithmic scale on the second axes
ax2.set_yscale('log')

# Display the plot
plt.show()

# %% [markdown]
# In this modified example, we create a figure and axes using plt.subplots(). We plot y1 on the first axes (ax1) using ax1.plot(), specifying the color as 'b'. We set the y-label color to blue using ax1.set_ylabel(color='b') and customize the tick colors using ax1.tick_params('y', colors='b'). We create a twin axes (ax2) sharing the x-axis with ax1 using ax1.twinx(). We plot y2 on the second axes using ax2.plot(), specifying the color as 'r'. We set the y-label color to red using ax2.set_ylabel(color='r') and customize the tick colors using ax2.tick_params('y', colors='r'). Additionally, we set the y-scale of ax2 to logarithmic using ax2.set_yscale('log'). This allows us to represent the data on ax2 with a logarithmic scale. Finally, we display the plot using plt.show().
#
# By utilizing these techniques, you can customize tick locations and labels, set tick formats, hide and customize spines, create twin axes, and use logarithmic scales to enhance your plots using Matplotlib. Experiment with different customization options and explore the vast possibilities Matplotlib offers to further enhance your tick and spine visualizations.

# %% [markdown]
# Chapter 14: Styles and Themes
#
# Section 14.1: Applying styles to plots
#
# Styles in Matplotlib allow you to change the overall appearance of your plots. Matplotlib provides a set of predefined styles that you can apply to your plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Apply a style to the plot
plt.style.use('seaborn-darkgrid')

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_24/999848442.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# In this example, we apply the 'seaborn-darkgrid' style to the plot using plt.style.use(). This style adds a dark background grid to the plot. You can choose from a variety of predefined styles available in Matplotlib or create your own custom styles.
#
# Section 14.2: Creating custom styles
#
# Matplotlib allows you to create your own custom styles to suit your specific plot aesthetics. Custom styles are defined using a JSON file. Let's explore an example:
#
# Create a file named custom_style.mplstyle with the following content:

# %% [markdown]
# axes.spines.left: True
# axes.spines.bottom: True
# axes.spines.right: False
# axes.spines.top: False
#
# axes.linewidth: 2.0
# axes.edgecolor: '#555555'
#
# xtick.major.size: 6
# ytick.major.size: 6
#
# font.family: 'serif'
# font.size: 12.0

# %% [markdown]
# Use the custom style in your plot:

# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Data
# x = np.linspace(0, 10, 100)
# y = np.sin(x)
#
# # Apply the custom style to the plot
# plt.style.use('custom_style.mplstyle')
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot data
# ax.plot(x, y)
#
# # Display the plot
# plt.show()

# %% [markdown]
# In this example, we create a custom style by defining the desired properties in the custom_style.mplstyle file. The properties include the appearance of spines, linewidth, edgecolor, tick sizes, font family, and font size. We apply the custom style to the plot using plt.style.use(), specifying the name of the custom style file. The plot will be styled according to the defined properties.
#
# Section 14.3: Using pre-defined themes
#
# Themes in Matplotlib provide a convenient way to quickly change the overall appearance of your plots. Themes are collections of predefined styles that can be applied to your plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Apply a theme to the plot
plt.style.use('ggplot')

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we apply the 'ggplot' theme to the plot using plt.style.use(). This theme emulates the appearance of the ggplot plotting package in R. You can choose from a variety of predefined themes available in Matplotlib.
#
# Section 14.4: Combining styles and themes
#
# Matplotlib allows you to combine multiple styles and themes to create a customized appearance for your plots. You can apply a style and then overlay a theme on top of it. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Apply a style to the plot
plt.style.use('seaborn-darkgrid')

# Apply a theme to the plot
plt.style.use('bmh')

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_24/1912503988.py:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# In this example, we apply the 'seaborn-darkgrid' style to the plot using plt.style.use(). Then, we apply the 'bmh' theme on top of it using plt.style.use(). The resulting plot will have the combined appearance of the selected style and theme.
#
# By utilizing these techniques, you can apply styles to your plots, create custom styles, use predefined themes, and combine styles and themes to achieve the desired visual aesthetics using Matplotlib. Experiment with different styles and themes to find the one that best suits your needs and enhances your plots.

# %% [markdown]
# Chapter 15: Saving and Exporting Plots
#
# Section 15.1: Saving plots to image files
#
# Matplotlib allows you to save your plots as image files in various formats. The savefig() function is used to save plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Save the plot as a PNG image file
plt.savefig('plot.png')

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot x and y using ax.plot(). We save the plot as a PNG image file using plt.savefig(), specifying the desired file name and extension.
#
# Section 15.2: Exporting plots to different file formats
#
# Matplotlib allows you to export your plots to different file formats, such as PDF, SVG, EPS, and more. You can specify the file format by providing the appropriate file extension in the savefig() function. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Save the plot as a PDF file
plt.savefig('plot.pdf')

# Save the plot as an SVG file
plt.savefig('plot.svg')

# Save the plot as an EPS file
plt.savefig('plot.eps')

# %% [markdown]
# In this modified example, we save the plot as a PDF file by specifying the file extension as .pdf. We also save the plot as an SVG file and an EPS file by specifying the file extensions as .svg and .eps, respectively.
#
# Section 15.3: Saving plots with transparent backgrounds
#
# Matplotlib allows you to save your plots with transparent backgrounds, which can be useful for overlaying plots on different backgrounds or combining multiple plots. You can specify the transparent parameter in the savefig() function. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Save the plot with a transparent background as a PNG image file
plt.savefig('plot_transparent.png', transparent=True)

# %% [markdown]
# In this modified example, we save the plot with a transparent background by setting transparent=True in the savefig() function. The resulting PNG image file will have a transparent background.
#
# Section 15.4: Saving plots with specified DPI
#
# Matplotlib allows you to save your plots with a specific DPI (dots per inch) resolution. The dpi parameter in the savefig() function is used to specify the DPI value. Let's modify the previous example to demonstrate this:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Save the plot with a specified DPI as a PNG image file
plt.savefig('plot_dpi.png', dpi=300)

# %% [markdown]
# In this modified example, we save the plot with a specified DPI value of 300 by setting dpi=300 in the savefig() function. The resulting PNG image file will have a higher resolution due to the increased DPI value.
#
# By utilizing these techniques, you can save your plots to image files, export them to different file formats, save them with transparent backgrounds, and specify the DPI resolution using Matplotlib. Experiment with different file formats, transparency options, and DPI values to achieve the desired output for your plots.

# %% [markdown]
# Chapter 16: Interactive Plots
#
# Section 16.1: Introduction to interactive plots
#
# Matplotlib provides various tools and libraries that enable the creation of interactive plots, allowing users to interact with and explore data in real-time. These interactive plots can enhance data visualization and provide a more engaging experience. Let's explore some techniques for creating interactive plots.
#
# Section 16.2: Interacting with plots using widgets
#
# Matplotlib's widgets module enables the creation of interactive plots with various widgets such as sliders, buttons, checkboxes, and more. These widgets allow users to dynamically modify plot elements, change data parameters, or control visualizations. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.widgets import Slider

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot initial data
line, = ax.plot(x, y)

# Create a slider widget
slider_ax = plt.axes([0.15, 0.05, 0.7, 0.03])
slider = Slider(slider_ax, 'Frequency', 1, 10, valinit=1, valstep=0.1)

# Update plot based on slider value
def update(val):
    frequency = slider.val
    line.set_ydata(np.sin(frequency * x))
    fig.canvas.draw_idle()

slider.on_changed(update)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot initial data using ax.plot(). We create a slider widget using Slider, specifying the slider's position on the figure using plt.axes(). We define an update function that is called whenever the slider value changes. Inside the update function, we modify the y-data of the plot based on the slider value. Finally, we use slider.on_changed() to connect the update function to the slider. When the slider value changes, the plot updates accordingly.
#
# Section 16.3: Embedding interactive plots in web applications
#
# Matplotlib can be embedded in web applications to create interactive plots that can be accessed and manipulated through a web browser. Libraries such as Flask or Django can be used to build web applications that incorporate interactive plots. Let's explore a basic example using Flask:

# %% [markdown]
# from flask import Flask, render_template
# import matplotlib.pyplot as plt
# import numpy as np
#
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     # Data
#     x = np.linspace(0, 10, 100)
#     y = np.sin(x)
#
#     # Create a figure and axes
#     fig, ax = plt.subplots()
#
#     # Plot data
#     ax.plot(x, y)
#
#     # Save the plot to a temporary file
#     plot_path = '/static/plot.png'
#     fig.savefig(f'static/plot.png')
#
#     return render_template('index.html', plot_path=plot_path)
#
# if __name__ == '__main__':
#     app.run()

# %% [markdown]
# In this example, we use Flask to create a web application. The index() function is decorated with @app.route('/') to define the home page route. Inside the index() function, we create a figure and axes using plt.subplots(). We plot data on the axes using ax.plot(). We save the plot as an image file to a temporary location. Finally, we render an HTML template (index.html) that includes the path to the plot image file.
#
# Section 16.4: Animating plots
#
# Matplotlib allows you to create animated plots, where the plot updates over time to visualize changing data or dynamic processes. Animations can be created using the animation module, which provides classes and functions for generating and saving animations. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Create an empty line plot
line, = ax.plot([], [])

# Update function for animation
def update(frame):
    line.set_data(x[:frame], y[:frame])  # Update plot data
    return line,

# Create animation
ani = animation.FuncAnimation(fig, update, frames=len(x), interval=100, blit=True)

# Display the animation
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We create an empty line plot using ax.plot(). We define an update function that is called for each frame of the animation. Inside the update function, we update the data of the line plot using line.set_data(). We create the animation using animation.FuncAnimation(), specifying the figure, update function, number of frames, interval between frames, and blit=True for efficient rendering. Finally, we display the animation using plt.show().
#
# By utilizing these techniques, you can create interactive plots using widgets, embed plots in web applications, and animate plots to enhance data exploration and visualization using Matplotlib. Experiment with different widget types, web frameworks, and animation parameters to create interactive and dynamic visualizations that suit your needs.

# %% [markdown]
# Chapter 16: Interactive Plots
#
# Section 16.1: Introduction to interactive plots
#
# Interactive plots allow users to dynamically explore and interact with data, providing a more engaging and flexible data visualization experience. Matplotlib offers various tools and libraries that enable the creation of interactive plots, allowing users to manipulate plot elements, change data parameters, and control visualizations in real-time.
#
# Section 16.2: Interacting with plots using widgets
#
# Matplotlib's widgets module provides a range of interactive widgets, such as sliders, buttons, checkboxes, dropdown menus, and more. These widgets can be used to modify plot elements, adjust data parameters, or toggle display options interactively. By connecting widget actions to update functions, plots can respond to user interactions dynamically. Here's an example:

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.widgets import Slider

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot initial data
line, = ax.plot(x, y)

# Create a slider widget
slider_ax = plt.axes([0.15, 0.05, 0.7, 0.03])
slider = Slider(slider_ax, 'Frequency', 1, 10, valinit=1, valstep=0.1)

# Update plot based on slider value
def update(val):
    frequency = slider.val
    line.set_ydata(np.sin(frequency * x))
    fig.canvas.draw_idle()

slider.on_changed(update)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot the initial data using ax.plot(). We create a slider widget using Slider, specifying its position and range. The update function is called whenever the slider value changes, modifying the plot data based on the frequency value. The on_changed method connects the update function to the slider, ensuring that the plot updates dynamically when the slider is adjusted.
#
# Section 16.3: Embedding interactive plots in web applications
#
# Matplotlib can be embedded in web applications using frameworks like Flask, Django, or Bokeh, enabling the creation of interactive plots accessible through web browsers. These frameworks provide functionality to handle HTTP requests and serve plots as dynamic web content. Here's a basic example using Flask:

# %% [markdown]
# from flask import Flask, render_template
# import matplotlib.pyplot as plt
# import numpy as np
#
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     # Data
#     x = np.linspace(0, 10, 100)
#     y = np.sin(x)
#
#     # Create a figure and axes
#     fig, ax = plt.subplots()
#
#     # Plot data
#     ax.plot(x, y)
#
#     # Save the plot to a temporary file
#     plot_path = '/static/plot.png'
#     fig.savefig(f'static/plot.png')
#
#     return render_template('index.html', plot_path=plot_path)
#
# if __name__ == '__main__':
#     app.run()

# %% [markdown]
# In this example, we use Flask to create a web application. The index() function is decorated with @app.route('/') to define the home page route. Inside the function, we create a figure and axes, plot data, and save the plot as an image file. We render an HTML template (index.html) that includes the path to the plot image file, enabling it to be displayed on the web page.
#
# Section 16.4: Animating plots
#
# Animations in Matplotlib allow you to create dynamic plots that change over time, visualizing evolving data or processes. The animation module provides classes and functions to generate and save animations. You can define update functions to modify plot elements in each frame of the animation. Here's an example:

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Create an empty line plot
line, = ax.plot([], [])

# Update function for animation
def update(frame):
    line.set_data(x[:frame], y[:frame])  # Update plot data
    return line,

# Create animation
ani = animation.FuncAnimation(fig, update, frames=len(x), interval=100, blit=True)

# Display the animation
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We create an empty line plot using ax.plot(). The update function is called for each frame of the animation, modifying the plot data to display a growing line. The FuncAnimation class creates the animation, specifying the figure, update function, number of frames, frame interval, and blit=True for efficient rendering. Finally, we display the animation using plt.show().
#
# By using interactive widgets, embedding plots in web applications, and creating animated plots, you can enhance the interactivity and engagement of your data visualizations using Matplotlib. Experiment with different widgets, explore web frameworks for interactive plotting, and animate plots to effectively communicate complex information or dynamic processes.

# %% [markdown]
# Chapter 17: Advanced Customizations
#
# Section 17.1: Customizing figure size and resolution
#
# Matplotlib allows you to customize the size and resolution of your figures to ensure they fit your desired output requirements. The figure size can be adjusted using the figsize parameter when creating a figure. The resolution can be specified by setting the DPI (dots per inch) value using the dpi parameter. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure with custom size and resolution
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)

# Plot data
ax.plot(x, y)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure with a custom size of 8 inches by 6 inches using the figsize parameter. We also set the DPI to 100 using the dpi parameter. The resulting figure will have the specified size and resolution.
#
# Section 17.2: Adding annotations and shapes to plots
#
# Matplotlib provides various functions for adding annotations and shapes to your plots, allowing you to highlight specific features or provide additional information. Annotations can include text, arrows, or lines, while shapes can be rectangles, circles, or polygons. Let's explore some examples:
#
# Adding text annotation:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Add text annotation
ax.text(5, 0.8, 'Max', fontsize=12, ha='center', va='center', bbox=dict(facecolor='yellow', edgecolor='black'))

# Display the plot
plt.show()

# %% [markdown]
# In this example, we add a text annotation to the plot using ax.text(). We specify the coordinates (5, 0.8) where the annotation should be placed, the text content ('Max'), the font size (12), and the alignment (ha='center', va='center'). We also provide a bounding box (bbox) to highlight the text with a yellow background and a black edge.
#
# Adding a shape (rectangle):

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Rectangle

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Add a rectangle shape
rect = Rectangle((3, -0.5), 2, 1, facecolor='red', alpha=0.3)
ax.add_patch(rect)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we add a rectangle shape to the plot using Rectangle from matplotlib.patches. We specify the coordinates (3, -0.5) as the bottom-left corner of the rectangle, the width (2), the height (1), the face color (facecolor='red'), and the transparency (alpha=0.3). We add the rectangle to the axes using ax.add_patch().
#
# Section 17.3: Fine-tuning plot appearance with rcParams
#
# Matplotlib's rcParams allows you to customize various plot appearance settings globally, affecting all plots in a script or session. This can be useful for setting default font styles, grid settings, line widths, and more. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Customize plot appearance using rcParams
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.linewidth'] = 2

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data
ax.plot(x, y)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we use rcParams to customize the plot appearance globally. We set the font family to 'serif', the font size to 12, enable the grid with True, and set the axis linewidth to 2. These settings will be applied to all subsequent plots in the script or session.
#
# Section 17.4: Using custom color maps
#
# Matplotlib provides a wide range of color maps to assign colors to plots, but you can also create your own custom color maps to suit specific visualization needs. Custom color maps can be created using the ListedColormap or LinearSegmentedColormap classes from matplotlib.colors. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a custom color map
colors = ['red', 'orange', 'yellow', 'green']
cmap = ListedColormap(colors)

# Create a figure and axes
fig, ax = plt.subplots()

# Plot data with custom color map
ax.scatter(x, y, c=x, cmap=cmap)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a custom color map using ListedColormap from matplotlib.colors. We specify a list of colors (['red', 'orange', 'yellow', 'green']) to define the custom color map. We assign colors based on the x-values of the scatter plot using c=x and apply the custom color map using cmap=cmap.
#
# By utilizing these techniques, you can customize the figure size and resolution, add annotations and shapes to plots, fine-tune plot appearance globally using rcParams, and create custom color maps to enhance your visualizations using Matplotlib. Experiment with different customization options to create visually appealing and informative plots tailored to your specific needs.

# %% [markdown]
# Chapter 18: Advanced Plotting Techniques
#
# Section 18.1: Streamplots and vector fields
#
# Matplotlib provides tools for visualizing vector fields and fluid flow using streamplots. Streamplots display the flow of a vector field through a plot of streamlines. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a grid of points
x, y = np.meshgrid(np.linspace(-2, 2, 20), np.linspace(-2, 2, 20))

# Define vector field components
u = -y
v = x

# Create a figure and axes
fig, ax = plt.subplots()

# Create a streamplot
ax.streamplot(x, y, u, v)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a grid of points using np.meshgrid() over a range of x and y values. We define the vector field components u and v. We create a streamplot using ax.streamplot(), providing the grid of points and the vector field components. The resulting plot displays the flow of the vector field through a set of streamlines.
#
# Section 18.2: Quiver plots
#
# Quiver plots are used to visualize vector fields using arrows to represent the direction and magnitude of the vectors. Matplotlib provides quiver() for creating quiver plots. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a grid of points
x, y = np.meshgrid(np.arange(-2, 2, 0.5), np.arange(-2, 2, 0.5))

# Define vector field components
u = -y
v = x

# Create a figure and axes
fig, ax = plt.subplots()

# Create a quiver plot
ax.quiver(x, y, u, v)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a grid of points using np.meshgrid() over a range of x and y values. We define the vector field components u and v. We create a quiver plot using ax.quiver(), providing the grid of points and the vector field components. The resulting plot displays arrows representing the direction and magnitude of the vectors.
#
# Section 18.3: 2D and 3D histograms
#
# Matplotlib allows you to create 2D and 3D histograms to visualize the distribution of data across two or three dimensions. Histograms provide a way to understand the frequency of values within specific bins or ranges. Let's consider an example of a 2D histogram:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a 2D histogram
ax.hist2d(x, y, bins=30, cmap='Blues')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data for the x and y coordinates. We create a figure and axes using plt.subplots(). We create a 2D histogram using ax.hist2d(), specifying the x and y data, the number of bins (bins=30), and the color map (cmap='Blues'). The resulting plot displays the distribution of data in a two-dimensional histogram.
#
# Section 18.4: Plotting on maps
#
# Matplotlib provides functionality for plotting data on maps, allowing you to visualize geographic or spatial data. The Basemap toolkit or the newer Cartopy library can be used for map projections and handling map features. Let's consider an example using Cartopy:

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Create a figure and axes with a specific projection
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

# Add map features
ax.coastlines()

# Plot data on the map
ax.plot(-122.4194, 37.7749, 'ro', transform=ccrs.PlateCarree())

# Display the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots() and specify the projection as ccrs.PlateCarree() using subplot_kw. We add coastlines to the plot using ax.coastlines(). We plot a point at the coordinates (-122.4194, 37.7749) using ax.plot(), specifying the transform as ccrs.PlateCarree() to convert the coordinates to the desired map projection. The resulting plot displays a map with coastlines and a point plotted on it.
#
# By utilizing these techniques, you can create streamplots and visualize vector fields, create quiver plots to represent vector fields, generate 2D and 3D histograms to analyze data distributions, and plot data on maps using Matplotlib. Experiment with different data and customization options to effectively visualize complex information and spatial data.

# %% [markdown]
# Chapter 19: Working with Dates and Times
#
# Section 19.1: Plotting time series data
#
# Matplotlib provides functionality to plot time series data, allowing you to visualize data over time. Time series data typically consists of observations or measurements recorded at different points in time. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a DataFrame with time series data
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
        'Value': [10, 20, 15, 25]}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])

# Create a figure and axes
fig, ax = plt.subplots()

# Plot time series data
ax.plot(df['Date'], df['Value'])

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a DataFrame with time series data, consisting of a 'Date' column and a 'Value' column. We convert the 'Date' column to a datetime type using pd.to_datetime(). We create a figure and axes using plt.subplots(). We plot the time series data using ax.plot(), providing the 'Date' column as the x-axis and the 'Value' column as the y-axis. The resulting plot displays the time series data.
#
# Section 19.2: Customizing date and time formatting
#
# Matplotlib allows you to customize the formatting of dates and times on the plot axes, enabling you to display them in a specific format. This can include the use of various date and time format codes to control the appearance of the dates and times. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# Create a DataFrame with time series data
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
        'Value': [10, 20, 15, 25]}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])

# Create a figure and axes
fig, ax = plt.subplots()

# Plot time series data
ax.plot(df['Date'], df['Value'])

# Format the x-axis as dates
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d, %Y'))

# Rotate the x-axis tick labels
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# Chapter 19: Working with Dates and Times
#
# Section 19.1: Plotting time series data
#
# Matplotlib provides functionality to plot time series data, allowing you to visualize data over time. Time series data typically consists of observations or measurements recorded at different points in time. Let's consider an example:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Create a DataFrame with time series data
# data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
#         'Value': [10, 20, 15, 25]}
# df = pd.DataFrame(data)
# df['Date'] = pd.to_datetime(df['Date'])
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot time series data
# ax.plot(df['Date'], df['Value'])
#
# # Display the plot
# plt.show()
# In this example, we create a DataFrame with time series data, consisting of a 'Date' column and a 'Value' column. We convert the 'Date' column to a datetime type using pd.to_datetime(). We create a figure and axes using plt.subplots(). We plot the time series data using ax.plot(), providing the 'Date' column as the x-axis and the 'Value' column as the y-axis. The resulting plot displays the time series data.
#
# Section 19.2: Customizing date and time formatting
#
# Matplotlib allows you to customize the formatting of dates and times on the plot axes, enabling you to display them in a specific format. This can include the use of various date and time format codes to control the appearance of the dates and times. Let's explore an example:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
# import matplotlib.dates as mdates
#
# # Create a DataFrame with time series data
# data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
#         'Value': [10, 20, 15, 25]}
# df = pd.DataFrame(data)
# df['Date'] = pd.to_datetime(df['Date'])
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot time series data
# ax.plot(df['Date'], df['Value'])
#
# # Format the x-axis as dates
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d, %Y'))
#
# # Rotate the x-axis tick labels
# plt.xticks(rotation=45)
#
# # Display the plot
# plt.show()
# In this example, we create a DataFrame with time series data, as in the previous example. We create a figure and axes using plt.subplots(). We plot the time series data. We use ax.xaxis.set_major_formatter() to set the date format of the x-axis tick labels. In this case, we use the format code %b %d, %Y to display the month, day, and year. We rotate the x-axis tick labels using plt.xticks(rotation=45) to prevent overlapping. The resulting plot displays the time series data with customized date formatting.
#
# Section 19.3: Handling time zones
#
# When working with dates and times, it's important to consider time zones. Matplotlib provides functionality to handle time zones, allowing you to convert and display dates and times in different time zones. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pytz

# Create a DataFrame with time series data
data = {'Date': ['2023-01-01 00:00:00', '2023-01-02 00:00:00', '2023-01-03 00:00:00', '2023-01-04 00:00:00'],
        'Value': [10, 20, 15, 25]}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])

# Convert dates to a specific time zone
df['Date'] = df['Date'].dt.tz_localize(pytz.utc).dt.tz_convert('US/Eastern')

# Create a figure and axes
fig, ax = plt.subplots()

# Plot time series data
ax.plot(df['Date'], df['Value'])

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a DataFrame with time series data, as in the previous examples. We convert the 'Date' column to a datetime type using pd.to_datetime(). We then localize the dates to UTC using dt.tz_localize() and convert them to the 'US/Eastern' time zone using dt.tz_convert(). We create a figure and axes using plt.subplots() and plot the time series data. The resulting plot displays the time series data converted to the 'US/Eastern' time zone.
#
# Section 19.4: Plotting events and intervals
#
# Matplotlib allows you to plot events and intervals on time series plots, providing additional visual context. This can include highlighting specific periods, indicating events, or marking important time intervals. Let's explore an example:

# %% [markdown]
# import matplotlib.pyplot as plt
# import pandas as pd
# import matplotlib.dates as mdates
#
# # Create a DataFrame with time series data
# data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04'],
#         'Value': [10, 20, 15, 25]}
# df = pd.DataFrame(data)
# df['Date'] = pd.to_datetime(df['Date'])
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot time series data
# ax.plot(df['Date'], df['Value'])
#
# # Highlight a specific period
# ax.axvspan('2023-01-02', '2023-01-03', alpha=0.3, color='yellow')
#
# # Mark an event
# ax.axvline('2023-01-04', color='red', linestyle='--')
#
# # Format the x-axis as dates
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d, %Y'))
#
# # Display the plot
# plt.show()

# %% [markdown]
# In this example, we create a DataFrame with time series data, as in the previous examples. We create a figure and axes using plt.subplots() and plot the time series data. We use ax.axvspan() to highlight a specific period on the plot, specifying the start and end dates, alpha (transparency), and color. We use ax.axvline() to mark an event on the plot, specifying the date, color, and linestyle. The resulting plot displays the time series data with a highlighted period and a marked event.
#
# By utilizing these techniques, you can effectively plot time series data, customize date and time formatting, handle time zones, and plot events and intervals on time series plots using Matplotlib. Experiment with different date and time formats, time zones, and visualization options to create informative and visually appealing time-based plots.

# %% [markdown]
# Chapter 20: Statistical Visualization
#
# Section 20.1: Box plots and violin plots for distribution visualization
#
# Box plots and violin plots are useful for visualizing the distribution of data and identifying key statistical properties such as the median, quartiles, and outliers. Matplotlib provides functions to create these plots. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.normal(0, 1, size=(100, 4))

# Create a figure and axes
fig, ax = plt.subplots()

# Create a box plot
ax.boxplot(data)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data using np.random.normal(). We create a figure and axes using plt.subplots(). We create a box plot using ax.boxplot(), providing the data to be visualized. The resulting plot displays the box plots for each column of the data, representing the distribution of values.
#
# Violin plots provide a similar visualization, but also display the kernel density estimation of the data. Here's an example of a violin plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.normal(0, 1, size=(100, 4))

# Create a figure and axes
fig, ax = plt.subplots()

# Create a violin plot
ax.violinplot(data)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data as before. We create a figure and axes. We create a violin plot using ax.violinplot(), providing the data to be visualized. The resulting plot displays the violin plots for each column of the data, representing the distribution along with the kernel density estimation.
#
# Section 20.2: Heatmaps and correlation matrices
#
# Heatmaps and correlation matrices are effective for visualizing relationships and patterns in large datasets. Matplotlib provides functionality to create these plots. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.rand(10, 10)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a heatmap
im = ax.imshow(data, cmap='hot')

# Add a colorbar
cbar = ax.figure.colorbar(im, ax=ax)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data using np.random.rand(). We create a figure and axes. We create a heatmap using ax.imshow(), providing the data and the colormap ('hot' in this case). We add a colorbar using ax.figure.colorbar(), specifying the colorbar and the axes to attach it to. The resulting plot displays the heatmap of the data.
#
# Correlation matrices are commonly visualized using heatmaps. Here's an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
data = np.random.rand(10, 10)

# Compute correlation matrix
corr_matrix = np.corrcoef(data, rowvar=False)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a heatmap of the correlation matrix
im = ax.imshow(corr_matrix, cmap='coolwarm')

# Add a colorbar
cbar = ax.figure.colorbar(im, ax=ax)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data as before. We compute the correlation matrix using np.corrcoef(). We create a figure and axes. We create a heatmap of the correlation matrix using ax.imshow(), specifying the colormap ('coolwarm' in this case). We add a colorbar using ax.figure.colorbar(). The resulting plot displays the heatmap of the correlation matrix.
#
# Section 20.3: Scatter plots with regression lines
#
# Scatter plots with regression lines are useful for visualizing the relationship between two variables and fitting a regression model to the data. Matplotlib provides functionality to create scatter plots with regression lines. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
x = np.random.randn(100)
y = 2 * x + np.random.randn(100)

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(x, y)

# Fit a linear regression line
m, b = np.polyfit(x, y, deg=1)
ax.plot(x, m * x + b, color='red')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data for x and y. We create a figure and axes. We create a scatter plot using ax.scatter(), providing the x and y data. We fit a linear regression line using np.polyfit() and plot it using ax.plot(), specifying the line equation and color. The resulting plot displays the scatter plot with the regression line.
#
# Section 20.4: Visualizing uncertainty with error bars
#
# Error bars are used to represent uncertaintyin data and can be added to plots to visualize variations or confidence intervals. Matplotlib provides functionality to create error bars in different styles. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
x = np.arange(1, 6)
y = np.array([1, 2, 4, 3, 5])
y_err = np.array([0.5, 0.8, 0.3, 0.6, 0.4])

# Create a figure and axes
fig, ax = plt.subplots()

# Create a line plot with error bars
ax.errorbar(x, y, yerr=y_err, fmt='o', capsize=3)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data for x and y, and also define the error values y_err. We create a figure and axes. We create a line plot with error bars using ax.errorbar(), providing the x and y data, the error values (yerr), the marker style (fmt='o'), and the size of the caps on the error bars (capsize=3). The resulting plot displays the line plot with error bars representing the uncertainty in the data.
#
# By utilizing these techniques, you can create box plots and violin plots to visualize distributions, generate heatmaps and correlation matrices to identify patterns and relationships in data, create scatter plots with regression lines to explore relationships between variables, and add error bars to visualize uncertainty in data using Matplotlib. Experiment with different styles and customization options to effectively convey statistical information through visualizations.

# %% [markdown]
# Section 21.1: Plotting data on maps
#
# Matplotlib provides functionality to plot data on maps, allowing you to create visualizations of geographic data. The Basemap toolkit or the newer Cartopy library can be used for map projections and handling map features. Let's explore an example using Cartopy:

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# Create a figure and axes with a specific projection
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

# Add map features
ax.coastlines()

# Plot data on the map
ax.plot([-122.4194, -73.935242], [37.7749, 40.712776], 'ro-', transform=ccrs.PlateCarree())

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots() and specify the projection as ccrs.PlateCarree() using subplot_kw. We add coastlines to the plot using ax.coastlines(). We plot a line connecting two points at the coordinates (-122.4194, 37.7749) and (-73.935242, 40.712776) using ax.plot(), specifying the transform as ccrs.PlateCarree() to convert the coordinates to the desired map projection. The resulting plot displays a map with coastlines and a line connecting the two points.
#
# Section 21.2: Choropleth maps
#
# Choropleth maps are used to represent data using different colors or patterns for different regions or areas. Matplotlib can be used to create choropleth maps by associating data values with specific regions. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# Load shapefile data
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a figure and axes
fig, ax = plt.subplots()

# Plot the choropleth map
world.plot(column='pop_est', cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8')

# Add a title
ax.set_title('World Population')

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_24/198357356.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# In this example, we load shapefile data using geopandas library. We create a figure and axes using plt.subplots(). We plot the choropleth map using world.plot(), specifying the column containing the data to be represented ('pop_est' in this case), the colormap ('OrRd' in this case), the linewidth, the axes to plot on, and the edge color. We add a title to the plot using ax.set_title(). The resulting plot displays a choropleth map of world population.
#
# Section 21.3: Point maps and bubble maps
#
# Point maps and bubble maps are used to represent individual points or locations on a map. Matplotlib provides functionality to create point maps and bubble maps using scatter plots. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# Load shapefile data
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# Create a figure and axes
fig, ax = plt.subplots()

# Plot point map
cities.plot(ax=ax, marker='o', color='red', markersize=5)

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_24/2662208300.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_cities' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %% [markdown]
# In this example, we load shapefile data containing cities using geopandas library. We create a figure and axes using plt.subplots(). We plot the point map using cities.plot(), specifying the marker style ('o' in this case), the color ('red' in this case), and the marker size. The resulting plot displays a point map of the cities.
#
# To create a bubble map, you can modify the marker size based on a numeric value associated with each point. Let's consider an example:

# %% [markdown]
# import matplotlib.pyplot as plt
# import geopandas as gpd
#
# # Load shapefile data
# cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot bubble map
# cities.plot(ax=ax, marker='o', color='red', markersize=cities['pop_max'] / 1e5)
#
# # Display the plot
# plt.show()

# %% [markdown]
# In this example, we load shapefile data as before. We plot the bubble map using cities.plot(), but this time we use cities['pop_max'] to specify the marker size. The marker size is calculated by dividing the population value by 1e5 to scale it appropriately. The resulting plot displays a bubble map where the size of each marker corresponds to the population value of the city.
#
# Section 21.4: Geospatial projections and transformations
#
# Matplotlib provides functionality to work with different geospatial projections and perform transformations on geographic data. This allows you to accurately represent data on different map projections and handle coordinate transformations. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Create a figure and axes with a specific projection
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.Mercator()})

# Add map features
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS)

# Plot data on the map
ax.plot([-122.4194, -73.935242], [37.7749, 40.712776], 'ro-', transform=ccrs.PlateCarree())

# Display the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/conda/lib/python3.10/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_ocean.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/conda/lib/python3.10/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots() and specify the projection as ccrs.Mercator() using subplot_kw. We add map features such as land, ocean, coastline, and borders using ax.add_feature(). We plot a line connecting two points at the coordinates (-122.4194, 37.7749) and (-73.935242, 40.712776) using ax.plot(), specifying the transform as ccrs.PlateCarree() to convert the coordinates to the desired map projection. The resulting plot displays a map with map features and a line connecting the two points.
#
# By utilizing these techniques, you can plot data on maps, create choropleth maps, visualize point maps and bubble maps, and work with geospatial projections and transformations using Matplotlib. Experiment with different map data and customization options to effectively represent geographic information and spatial data.

# %% [markdown]
# Chapter 22: Interactive Geospatial Visualization
#
# Section 22.1: Interactive maps with tooltips and interactivity
#
# Matplotlib provides functionality to create interactive maps with tooltips and interactivity, allowing users to explore and interact with geospatial data. The mplleaflet library can be used to convert Matplotlib plots into interactive Leaflet maps. Let's explore an example:

# %% [markdown]
# import matplotlib.pyplot as plt
# import mplleaflet
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Plot data on the map
# ax.plot([-122.4194, -73.935242], [37.7749, 40.712776], 'ro-')
#
# # Convert the plot to an interactive Leaflet map
# mplleaflet.display(fig=fig)

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots(). We plot a line connecting two points at the coordinates (-122.4194, 37.7749) and (-73.935242, 40.712776) using ax.plot(). We convert the plot to an interactive Leaflet map using mplleaflet.display(), passing the figure object fig. The resulting plot is displayed as an interactive map with tooltips and interactivity.
#
# Section 22.2: Adding layers and overlays to maps
#
# Matplotlib allows you to add layers and overlays to maps, enabling you to visualize multiple datasets on the same map. You can plot additional data on top of an existing map to create layered visualizations. Let's consider an example:

# %% [markdown]
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature
#
# # Create a figure and axes with a specific projection
# fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})
#
# # Add map features
# ax.add_feature(cfeature.LAND)
# ax.add_feature(cfeature.OCEAN)
# ax.add_feature(cfeature.COASTLINE)
# ax.add_feature(cfeature.BORDERS)
#
# # Plot data on the map
# ax.plot([-122.4194, -73.935242], [37.7749, 40.712776], 'ro-', transform=ccrs.PlateCarree())
#
# # Add a layer with additional data
# ax.plot([-118.2437, -77.0369], [34.0522, 38.9072], 'bo-', transform=ccrs.PlateCarree())
#
# # Display the plot
# plt.show()

# %% [markdown]
# In this example, we create a figure and axes using plt.subplots() and specify the projection as ccrs.PlateCarree() using subplot_kw. We add map features such as land, ocean, coastline, and borders using ax.add_feature(). We plot a line connecting two points at the coordinates (-122.4194, 37.7749) and (-73.935242, 40.712776) using ax.plot(), specifying the transform as ccrs.PlateCarree(). We then add another layer with a different line connecting two points at the coordinates (-118.2437, 34.0522) and (-77.0369, 38.9072) on top of the existing map. The resulting plot displays the base map with multiple layers and data overlaid.
#
# Section 22.3: Geospatial clustering and heatmaps
#
# Matplotlib provides functionality to perform geospatial clustering and create heatmaps to visualize the density or intensity of data points. You can use clustering algorithms to group similar data points and create visual representations of the clusters. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# Generate random data
np.random.seed(0)
x = np.random.rand(100)
y = np.random.rand(100)

# Perform clustering
kmeans = KMeans(n_clusters=3, random_state=0).fit(np.column_stack((x, y)))
labels = kmeans.labels_

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot with different colors for clusters
scatter = ax.scatter(x, y, c=labels, cmap='viridis')

# Add a colorbar
cbar = plt.colorbar(scatter)

# Display the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# In this example, we generate random data for x and y. We perform clustering using the KMeans algorithm from sklearn.cluster. We create a scatter plot using ax.scatter(), specifying the data points, the cluster labels as the color values, and the colormap ('viridis' in this case). We add a colorbar using plt.colorbar() to display the color scale. The resulting plot displays the scatter plot with different colors representing the clusters.
#
# Heatmaps can be created using density-based clustering algorithms or by aggregating data within specific regions. Let's consider an example using a density-based clustering algorithm:

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN

# Generate random data
np.random.seed(0)
x = np.random.randn(100)
y = np.random.randn(100)

# Perform clustering
dbscan = DBSCAN(eps=0.3, min_samples=5).fit(np.column_stack((x, y)))
labels = dbscan.labels_

# Create a figure and axes
fig, ax = plt.subplots()

# Create a scatter plot with different colors for clusters
scatter = ax.scatter(x, y, c=labels, cmap='viridis')

# Add a colorbar
cbar = plt.colorbar(scatter)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we generate random data as before. We perform clustering using the DBSCAN algorithm from sklearn.cluster. We create a scatter plot with different colors representing the clusters. The resulting plot displays the scatter plot with different colors representing the clusters based on the density-based clustering algorithm.
#
# Section 22.4: Animated geospatial visualizations
#
# Matplotlib allows you to create animated geospatial visualizations to showcase changes or trends over time. You can utilize the FuncAnimation class to animate the plots. Let's explore an example:

# %% [markdown]
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature
# from matplotlib.animation import FuncAnimation
#
# # Create a figure and axes with a specific projection
# fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})
#
# # Add map features
# ax.add_feature(cfeature.LAND)
# ax.add_feature(cfeature.OCEAN)
# ax.add_feature(cfeature.COASTLINE)
# ax.add_feature(cfeature.BORDERS)
#
# # Initialize empty line object for animation
# line, = ax.plot([], [], 'bo-', transform=ccrs.PlateCarree())
#
# # Define animation update function
# def update(frame):
#     # Generate random data for animation
#     np.random.seed(frame)
#     lon = np.random.uniform(low=-180, high=180, size=10)
#     lat = np.random.uniform(low=-90, high=90, size=10)
#
#     # Update line data
#     line.set_data(lon, lat)
#
#     return line,
#
# # Create animation
# animation = FuncAnimation(fig, update, frames=10, interval=500, blit=True)
#
# # Display the animation
# plt.show()

# %% [markdown]
# In this example, we createa figure and axes using plt.subplots() and specify the projection as ccrs.PlateCarree() using subplot_kw. We add map features such as land, ocean, coastline, and borders using ax.add_feature(). We initialize an empty line object for the animation using ax.plot().
#
# We define an animation update function, update(frame), which is called for each frame of the animation. In this function, we generate random data for longitude (lon) and latitude (lat). We update the data of the line object using line.set_data() with the new longitude and latitude values.
#
# We create the animation using FuncAnimation(), passing the figure object fig, the update function update, the number of frames, and the interval between frames in milliseconds. We set blit=True for better performance.
#
# The resulting plot displays an animated geospatial visualization where the points on the map change randomly over time.
#
# By utilizing these techniques, you can create interactive maps with tooltips and interactivity, add layers and overlays to maps, perform geospatial clustering and create heatmaps, and create animated geospatial visualizations using Matplotlib. Experiment with different datasets, customization options, and animation parameters to effectively visualize geospatial data and showcase dynamic patterns or trends.

# %% [markdown]
# Chapter 23: Network Visualization
#
# Section 23.1: Visualizing networks and graphs
#
# Matplotlib provides functionality to visualize networks and graphs, allowing you to represent and analyze complex systems with interconnected nodes and edges. The NetworkX library is commonly used for creating and manipulating graphs, and Matplotlib can be used to visualize them. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create an empty graph
G = nx.Graph()

# Add nodes to the graph
G.add_nodes_from([1, 2, 3, 4, 5])

# Add edges to the graph
G.add_edges_from([(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)])

# Create a figure and axes
fig, ax = plt.subplots()

# Draw the graph
pos = nx.spring_layout(G)  # Set the layout algorithm
nx.draw_networkx(G, pos=pos, with_labels=True, node_color='lightblue', edge_color='gray')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create an empty graph using nx.Graph(). We add nodes to the graph using G.add_nodes_from() and specify a list of nodes. We add edges to the graph using G.add_edges_from() and specify a list of edges as tuples. We create a figure and axes using plt.subplots(). We draw the graph using nx.draw_networkx(), specifying the graph, the layout algorithm (spring_layout in this case), whether to show labels, node color, and edge color. The resulting plot displays the graph with nodes and edges.
#
# Section 23.2: Node and edge customization
#
# Matplotlib allows you to customize the appearance of nodes and edges in network visualizations, enabling you to highlight specific features or attributes of the network. You can modify the color, size, shape, and other visual properties of nodes and edges. Let's consider an example:

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a graph
G = nx.Graph()

# Add nodes to the graph with attributes
G.add_nodes_from([(1, {'color': 'red', 'size': 200}), (2, {'color': 'blue', 'size': 100}), (3, {'color': 'green', 'size': 150})])

# Add edges to the graph
G.add_edges_from([(1, 2), (2, 3), (3, 1)])

# Create a figure and axes
fig, ax = plt.subplots()

# Draw the graph with customized nodes and edges
pos = nx.circular_layout(G)  # Set the layout algorithm
node_colors = [data['color'] for _, data in G.nodes(data=True)]
node_sizes = [data['size'] for _, data in G.nodes(data=True)]
edge_colors = 'gray'
nx.draw_networkx(G, pos=pos, with_labels=True, node_color=node_colors, node_size=node_sizes, edge_color=edge_colors)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a graph and add nodes with attributes using G.add_nodes_from(). Each node is assigned a dictionary with color and size attributes. We add edges to the graph as before. We create a figure and axes using plt.subplots(). We draw the graph using nx.draw_networkx(), specifying the layout algorithm (circular_layout in this case), whether to show labels, node colors, node sizes, and edge color. The node colors and sizes are extracted from the attributes assigned to the nodes. The resulting plot displays the graph with customized nodes and edges.
#
# Section 23.3: Community detection and layout algorithms
#
# Matplotlib can be used to visualize community detection in networks, where nodes are grouped into communities based on their connections or attributes. The community module from NetworkX provides community detection algorithms, and layout algorithms can be used to position the nodes in a visually appealing way. Let's explore an example:

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms import community
from networkx.generators.community import LFR_benchmark_graph

# Generate a benchmark graph with communities
G = LFR_benchmark_graph(n=100, tau1=2, tau2=1.5, mu=0.1, average_degree=5, min_community=10, seed=0)

# Detect communities
communities = community.greedy_modularity_communities(G)

# Create a figure and axes
fig, ax = plt.subplots()

# Set the layout algorithm
pos = nx.spring_layout(G)

# Draw nodes with different colors for each community
for i, community_nodes in enumerate(communities):
    nx.draw_networkx_nodes(G, pos, nodelist=list(community_nodes), node_color=plt.cm.Set1(i), node_size=100, ax=ax)

# Draw edges
nx.draw_networkx_edges(G, pos, edge_color='gray', alpha=0.5, ax=ax)

# Display the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:433: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   node_collection = ax.scatter(

# %% [markdown]
# In this example, we generate a benchmark graph with communities using LFR_benchmark_graph() from networkx.generators.community. We detect communities using the greedy_modularity_communities() function from networkx.algorithms.community. We create a figure and axes using plt.subplots(). We set the layout algorithm to spring_layout using nx.spring_layout(). We draw nodes with different colors for each community using nx.draw_networkx_nodes(), iterating over the communities and assigning different colors from the colormap plt.cm.Set1(). We draw edges using nx.draw_networkx_edges(). The resulting plot displays the graph with nodes colored according to their communities.
#
# Section 23.4: Interactive network visualization
#
# Matplotlib supports interactive network visualization by integrating with other libraries such as NetworkX, pyvis, or mpld3. These libraries allow you to create interactive network visualizations with features such as zooming, panning, tooltips, and interactive node exploration. Let's consider an example using pyvis:

# %% [markdown]
# import networkx as nx
# from pyvis.network import Network
#
# # Create a graph
# G = nx.Graph()
#
# # Add nodes to the graph
# G.add_nodes_from([1, 2, 3, 4, 5])
#
# # Add edges to the graph
# G.add_edges_from([(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)])
#
# # Create an interactive network visualization
# nt = Network(height='500px', width='500px', notebook=True)
# nt.from_nx(G)
# nt.show('network.html')

# %% [markdown]
# In this example, we create a graph and add nodes and edges as before. We create an instance of Network from pyvis.network. We convert the NetworkX graph to pyvis using nt.from_nx(). We display the interactive visualization using nt.show(), specifying the output file as 'network.html'. The resulting visualization can be viewed in a web browser and will provide interactive features.
#
# By utilizing these techniques, you can visualize networks and graphs, customize nodes and edges, perform community detection and layout algorithms, and create interactive network visualizations using Matplotlib. Experiment with different graph structures, customizationoptions, and interactive features to effectively represent and explore complex network data.

# %% [markdown]
# Chapter 24: Plotting with Pandas
#
# Section 24.1: Plotting with Pandas Series and DataFrames
#
# Pandas provides built-in plotting functionality that integrates with Matplotlib, making it easy to create visualizations directly from Series and DataFrames. Let's explore an example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Pandas Series
data = pd.Series([1, 3, 2, 4, 5])

# Plot the Series
data.plot()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a Pandas Series data with values [1, 3, 2, 4, 5]. We plot the Series using the plot() method, which automatically creates a line plot. Finally, we display the plot using plt.show(). The resulting plot displays a simple line plot of the Series data.
#
# You can also plot Pandas DataFrames, which allows you to visualize multiple columns or variables. Let's consider an example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Pandas DataFrame
data = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [5, 4, 3, 2, 1]})

# Plot the DataFrame
data.plot()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a Pandas DataFrame data with two columns 'A' and 'B'. We plot the DataFrame, which creates a line plot for each column. The resulting plot displays two lines representing the data in columns 'A' and 'B'.
#
# Section 24.2: Grouping and aggregating data for visualization
#
# Pandas allows you to group and aggregate data, making it easy to create visualizations based on summarized data. You can use the groupby() function to group data based on one or more columns, and then apply an aggregation function such as sum(), mean(), or count(). Let's explore an example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Pandas DataFrame
data = pd.DataFrame({'Category': ['A', 'A', 'B', 'B', 'A'],
                     'Value': [1, 2, 3, 4, 5]})

# Group and aggregate the data
grouped_data = data.groupby('Category').sum()

# Plot the aggregated data
grouped_data.plot(kind='bar')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a Pandas DataFrame data with two columns 'Category' and 'Value'. We group the data by the 'Category' column using groupby('Category') and apply the sum() aggregation function to compute the sum of 'Value' for each category. We then plot the aggregated data as a bar plot using kind='bar' in the plot() function. The resulting plot displays a bar chart with the summed values for each category.
#
# Section 24.3: Plotting time series data with Pandas
#
# Pandas provides convenient functionality to handle time series data and create time-based visualizations. You can set a column with datetime values as the index of the DataFrame, which enables various time-based operations and plot types. Let's consider an example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Pandas DataFrame with a datetime index
data = pd.DataFrame({'Value': [1, 2, 3, 4, 5]},
                    index=pd.date_range('2022-01-01', periods=5, freq='D'))

# Plot the time series data
data.plot()

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a Pandas DataFrame data with a single column 'Value' and a datetime index using pd.date_range(). The index is set to a range of dates starting from '2022-01-01' with a frequency of 'D' (daily). We plot the time series data using plot(), which creates a line plot with the datetime index on the x-axis. The resulting plot displays the time series data as a line chart.
#
# Section 24.4: Combining Matplotlib and Pandas plots
#
# You can combine Matplotlib and Pandas plots to create more customized visualizations. After creating a plot with Pandas, you can further modify it using Matplotlib functions. Let's explore an example:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a Pandas DataFrame
data = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [5, 4, 3, 2, 1]})

# Plot the DataFrame with Pandas
ax = data.plot()

# Customize the plot with Matplotlib
ax.set_title('Custom Plot')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Display the plot
plt.show()

# %% [markdown]
# In this example, we create a Pandas DataFrame data with two columns 'A' and 'B'. We plot the DataFrame using data.plot(), which returns an AxesSubplot object. We store this object in the variable ax to further customize the plot. We use Matplotlib functions such as set_title(), set_xlabel(), and set_ylabel() to customize the plot title, x-axis label, and y-axis label, respectively. Finally, we display the plot using plt.show(). The resulting plot displays the DataFrame plot with the custom title and axis labels.
#
# By utilizing these techniques, you can create visualizations directly from Pandas Series and DataFrames, group and aggregate data for visualization, plot time series data, and combine Pandas and Matplotlib plots to create customized visualizations using Pandas. Experiment with different plot types, aggregation functions, and customization options to effectively analyze and visualize your data.

# %% [markdown]
# Chapter 25: Plotting with Seaborn
#
# Section 25.1: Introduction to Seaborn library
#
# Seaborn is a Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics. Seaborn is particularly useful for visualizing complex datasets and exploring relationships between variables. To use Seaborn, you need to install it separately, as it is not included in the standard Python distribution. Let's explore an example:

# %%
import seaborn as sns

# Load a built-in dataset from Seaborn
tips = sns.load_dataset("tips")

# Display the first few rows of the dataset
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# In this example, we use the load_dataset() function from Seaborn to load a built-in dataset called "tips". The dataset contains information about restaurant tips, including variables such as total bill, tip amount, gender, and smoker status. We display the first few rows of the dataset using print(tips.head()).
#
# Section 25.2: Plotting statistical relationships with Seaborn
#
# Seaborn provides several functions for visualizing statistical relationships between variables. These functions make it easy to explore patterns, correlations, and distributions in your data. Let's consider an example using the "tips" dataset:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "tips" dataset
tips = sns.load_dataset("tips")

# Create a scatter plot with a regression line
sns.scatterplot(x="total_bill", y="tip", data=tips)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we load the "tips" dataset using sns.load_dataset(). We create a scatter plot using sns.scatterplot(), specifying the x-axis variable as "total_bill", the y-axis variable as "tip", and the dataset as tips. The resulting plot displays a scatter plot of the relationship between total bill and tip amount, with a regression line showing the overall trend.
#
# Seaborn provides many other functions for visualizing statistical relationships, including sns.lineplot() for line plots, sns.barplot() for bar plots, sns.boxplot() for box plots, and sns.violinplot() for violin plots, among others.
#
# Section 25.3: Visualizing categorical data with Seaborn
#
# Seaborn offers various functions for visualizing categorical data, allowing you to explore and compare distributions across different categories. These plots are useful when working with variables such as gender, smoker status, or day of the week. Let's explore an example using the "tips" dataset:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "tips" dataset
tips = sns.load_dataset("tips")

# Create a box plot of tips grouped by day of the week
sns.boxplot(x="day", y="tip", data=tips)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we load the "tips" dataset using sns.load_dataset(). We create a box plot using sns.boxplot(), specifying the x-axis variable as "day", the y-axis variable as "tip", and the dataset as tips. The resulting plot displays a box plot of the distribution of tip amounts grouped by the day of the week.
#
# Seaborn provides several other functions for visualizing categorical data, including sns.barplot() for bar plots, sns.countplot() for counting occurrences, and sns.violinplot() for violin plots.
#
# Section 25.4: Customizing Seaborn plots
#
# Seaborn allows you to customize your plots by adjusting various visual parameters, such as color palettes, styles, and context. These customizations can enhance the appearance and readability of your visualizations. Let's consider an example:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "tips" dataset
tips = sns.load_dataset("tips")

# Set the Seaborn style and context
sns.set(style="darkgrid", context="talk")

# Create a scatter plot with a regression line
sns.scatterplot(x="total_bill", y="tip", data=tips)

# Display the plot
plt.show()

# %% [markdown]
# In this example, we load the "tips" dataset using sns.load_dataset(). We set the Seaborn style to "darkgrid" and the context to "talk" using sns.set(). We create a scatter plot as before using sns.scatterplot(). The resulting plot uses the specified style and context, which can improve the visual appearance and clarity of the plot.
#
# You can further customize Seaborn plots by modifying parameters such as color palettes, font sizes, plot scales, and more. Seaborn provides functions such as sns.set_palette(), sns.set_context(), and sns.set_style() for these customizations.
#
# By utilizing these techniques, you can leverage the power of Seaborn to plot statistical relationships, visualize categorical data, and customize your visualizations to effectively communicate insights from your data. Experiment with different plot types, customization options, and datasets to create visually appealing and informative visualizations.
